# %%
setwd("/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb")
library(data.table)

# %%
phenotypes <- fread('data/phenotypes/filtered_covar_phenotypes_cts.tsv.gz')

# %%
vcf <- fread(cmd =' zcat data/conditional/rare/combined/ukb_eur_wes_200k_chr21_maf0to5e-2_pLoF_damaging_missense.vcf.bgz | grep -v "##"')
