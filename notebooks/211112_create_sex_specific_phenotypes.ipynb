# %%
import hail as hl
import os
from ukb_utils import hail_init
from ukb_utils import genotypes
from ukb_utils import variants
from ukb_utils import samples

# %%
os.chdir('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/')
hail_init.hail_bmrc_init('logs/hail/hail_test_export.log', 'GRCh38')
# Out:
# Running on Apache Spark version 3.1.2
# SparkUI available at http://compe011.hpc.in.bmrc.ox.ac.uk:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.77-684f32d73643
# LOGGING: writing to logs/hail/hail_test_export.log

# %%
# load tables
#ht = hl.import_table('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/phenotypes/UKBB_WES200k_filtered_cts_phenotypes.tsv.gz', force = True).key_by('ID')
ht = hl.import_table('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/phenotypes/UKBB_WES200k_filtered_binary_phenotypes.tsv.gz', force = True).key_by('ID')
# Out:
# 2021-11-12 16:27:02 Hail: INFO: Loading 120 fields. Counts by type:
#   str: 120

# %%
ht_females = ht.filter(samples.get_females_expr(ht.ID))
ht_females.export('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/phenotypes/UKBB_WES200k_filtered_binary_phenotypes_females.tsv.gz')
# Out:
# 2021-11-12 16:27:04 Hail: INFO: merging 1 files totalling 15.1M...
# 2021-11-12 16:27:05 Hail: INFO: while writing:
#     /well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/phenotypes/UKBB_WES200k_filtered_binary_phenotypes_females.tsv.gz
#   merge time: 27.226ms
# 2021-11-12 16:27:08 Hail: INFO: Coerced sorted dataset
# 2021-11-12 16:27:17 Hail: INFO: merging 1 files totalling 15.1M...
# 2021-11-12 16:27:17 Hail: INFO: while writing:
#     /well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/phenotypes/UKBB_WES200k_filtered_binary_phenotypes_females.tsv.gz
#   merge time: 29.464ms

# %%
ht_males = ht.filter(~samples.get_females_expr(ht.ID))
ht_males.export('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/phenotypes/UKBB_WES200k_filtered_binary_phenotypes_males.tsv.gz')
# Out:
# 2021-11-12 16:27:21 Hail: INFO: Coerced sorted dataset
# 2021-11-12 16:27:30 Hail: INFO: merging 1 files totalling 12.5M...
# 2021-11-12 16:27:30 Hail: INFO: while writing:
#     /well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/phenotypes/UKBB_WES200k_filtered_binary_phenotypes_males.tsv.gz
#   merge time: 22.651ms

# %%
ht = hl.read_table('data/qc_new/TEST_ukb_wes_200k_chr15_variants_qc.ht')

# %%
ht.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'variant_qc': struct {
#         dp_stats: struct {
#             mean: float64,
#             stdev: float64,
#             min: float64,
#             max: float64
#         },
#         gq_stats: struct {
#             mean: float64,
#             stdev: float64,
#             min: float64,
#             max: float64
#         },
#         AC: array<int32>,
#         AF: array<float64>,
#         AN: int32,
#         homozygote_count: array<int32>,
#         call_rate: float64,
#         n_called: int64,
#         n_not_called: int64,
#         n_filtered: int64,
#         n_het: int64,
#         n_non_ref: int64,
#         het_freq_hwe: float64,
#         p_value_hwe: float64
#     }
#     'imputed_info': float64
#     'in_gnomad': bool
#     'worst_csq_for_variant_canonical': struct {
# ...
