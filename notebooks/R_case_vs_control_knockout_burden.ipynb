# %%
setwd("/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb")
library(data.table)

# %%
f1 <- "data/conditional/common/spa_iter/new_run_tuesday/ukb_eur_wes_200k_maf0to5e-2_AD_combined_pLoF_damaging_missense_cond_i2.mrg"
f2 <- "data/conditional/common/spa_iter/new_run_thursday/ukb_eur_wes_200k_maf0to5e-2_AD_combined_pLoF_damaging_missense_cond_i2.mrg"

# %%
d <- fread("data/phenotypes/")

# %%
d1 <- fread(f1)
d2 <- fread(f2)

# %%
sum(d1 == d2); sum(d1 != d2)
# Out:
# [1] 1602527
# [1] 623

# %%
#lst <- lapply(1:ncol(d), function(i) d1[i,] == d2[i, ])

# %%
d <- fread("data/phenotypes/curated_covar_phenotypes_binary_500k.tsv")

# %%
head(d, 1)
# Out:
#   eid     sex age ukbb.centre PC1     PC2    PC3     PC4    PC5    PC6
# 1 1000010 1   47  11018       -12.589 3.7667 -1.3232 4.0428 9.8237 -1.3497
#   <U+22EF>   POI_combined POI_combined_primary_care HYP_combined
# 1 <U+22EF> FALSE        FALSE                     FALSE
#   HYP_combined_primary_care DM_T1D DM_T2D DM_GD age2 age3   sex_age
# 1 FALSE                     FALSE  FALSE  FALSE 2209 103823 47

# %%
table(d$sex, d$PRE_combined_primary_care)
# Out:
#
#      FALSE   TRUE
#   0 260234  13094
#   1 219024  10061

# %%
row_different <- rowSums(d1 != d2) > 0
col_different <- colSums(d1 != d2) > 0

# %%
head(d2[row_different, col_different, with = FALSE])
# Out:
#   SE_c       p.value_c
# 1 0.06113250  7.16576e-13
# 2 0.30193300  4.04192e-01
# 3 0.00000000  0.00000e+00
# 4 0.05123210  8.48052e-05
# 5 0.00701739 2.88376e-146
# 6 0.01346880 2.53088e-159

# %%
hist(-log10(d2[row_different,]$p.value_c))
# Out:
# Plot with title "Histogram of -log10(d2[row_different, ]$p.value_c)"

# %%
hist(-log10(d1[row_different,]$p.value_c))
# Out:
# Plot with title "Histogram of -log10(d1[row_different, ]$p.value_c)"

# %%
d2[rowSums(d1 != d2) > 0 , ]
