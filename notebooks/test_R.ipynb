# %%
library(data.table)

# %%
# read in .bgz files 
zcat_fread <- function(path,...){
    cmd = paste("zcat", path)
    return(fread(cmd = cmd,...))
}

# %%
d <- zcat_fread('../data/variants/ukb_wes_200k_genebass_chr11.tsv.bgz')

# %%
d <- head(d)
colnames(d)
# Out:
#  [1] "locus"                       "alleles"
#  [3] "rsid"                        "qual"
#  [5] "filters"                     "info.AF"
#  [7] "info.AQ"                     "info.AC"
#  [9] "info.AN"                     "info.ExcessHet"
# [11] "variant_qc.dp_stats.mean"    "variant_qc.dp_stats.stdev"
# [13] "variant_qc.dp_stats.min"     "variant_qc.dp_stats.max"
# [15] "variant_qc.gq_stats.mean"    "variant_qc.gq_stats.stdev"
# [17] "variant_qc.gq_stats.min"     "variant_qc.gq_stats.max"
# [19] "variant_qc.AC"               "variant_qc.AF"
# [21] "variant_qc.AN"               "variant_qc.homozygote_count"
# [23] "variant_qc.call_rate"        "variant_qc.n_called"
# [25] "variant_qc.n_not_called"     "variant_qc.n_filtered"
# [27] "variant_qc.n_het"            "variant_qc.n_non_ref"
# [29] "variant_qc.het_freq_hwe"     "variant_qc.p_value_hwe"
# [31] "gb_AC"                       "gb_AF"
# [33] "gb_gene"                     "gb_annotation"

# %%
d$variant_qc.AF
# Out:
# [1] "[0.9999949921627347,5.0078372653202264E-6]"
# [2] "[0.9999724595154877,2.754048451223298E-5]"
# [3] "[0.9999799698546312,2.0030145368780015E-5]"
# [4] "[0.999992491665749,7.508334251018631E-6]"
# [5] "[0.9998320726248302,1.6792737516980715E-4]"
# [6] "[0.9999974973346614,2.5026653385855937E-6]"

# %%
# expand hail list items. E.g. an array list A = [x,y]
# will be converted into seperate columns, A1 = x and A2 = y.
# returns the full data.frame with the new collumns appended
expand_hail_list <- function(dt, name){
    stopifnot(name %in% colnames(dt))
    x <- dt[[name]]
    x <- gsub('(\\[)|(\\])|','',x)
    mat <- do.call(rbind, strsplit(x, split = ','))
    n <- ncol(mat)
    names <- paste0(name,1:n)
    colnames(mat) <- names
    return(cbind(dt, mat))
}

# %%
expand_hail_list(d, 'variant_qc.AF')
# Out:
#   locus        alleles   rsid          qual filters info.AF    info.AQ info.AC
# 1 chr11:193676 ["C","T"] 11:193676:C:T 28   NA      5.0078e-06 [28]     2
# 2 chr11:193679 ["T","C"] 11:193679:T:C 35   NA      2.7540e-05 [35]    11
# 3 chr11:193685 ["C","T"] 11:193685:C:T 33   NA      2.0030e-05 [33]     8
# 4 chr11:193702 ["C","T"] 11:193702:C:T 37   NA      7.5083e-06 [37]     3
# 5 chr11:193703 ["G","A"] 11:193703:G:A 47   NA      1.6793e-04 [47]    67
# 6 chr11:193712 ["G","T"] 11:193712:G:T 31   NA      2.5027e-06 [31]     1
#   info.AN info.ExcessHet <U+22EF>   variant_qc.n_het variant_qc.n_non_ref
# 1 399374  3.0104         <U+22EF>  2                2
# 2 399412  3.0108         <U+22EF> 11               11
# 3 399398  3.0108         <U+22EF>  8                8
# 4 399556  3.0103         <U+22EF>  3                3
# 5 398982  3.0550         <U+22EF> 67               67
# 6 399574  3.0103         <U+22EF>  1                1
#   variant_qc.het_freq_hwe variant_qc.p_value_hwe gb_AC gb_AF gb_gene
# 1 1.0016e-05              0.50000                NA    NA    NA
# 2 5.5080e-05              0.50007                NA    NA    NA
# 3 4.0060e-05              0.50004                NA    NA    NA
# 4 1.5017e-05              0.50000                NA    NA    NA
# 5 3.3580e-04              0.50276                NA    NA    NA
# 6 5.0053e-06              0.50000                NA    NA    NA
#   gb_annotation variant_qc.AF1     variant_qc.AF2
# 1 NA            0.9999949921627347 5.0078372653202264E-6
# 2 NA            0.9999724595154877 2.754048451223298E-5
# 3 NA            0.9999799698546312 2.0030145368780015E-5
# 4 NA            0.999992491665749  7.508334251018631E-6
# 5 NA            0.9998320726248302 1.6792737516980715E-4
# 6 NA            0.9999974973346614 2.5026653385855937E-6

# %%
files = sort(list.files('../data/variants', full.names = TRUE, pattern = 'genebass'))
files
# Out:
#  [1] "../data/variants/ukb_wes_200k_genebass_chr1.tsv.bgz"
#  [2] "../data/variants/ukb_wes_200k_genebass_chr10.tsv.bgz"
#  [3] "../data/variants/ukb_wes_200k_genebass_chr11.tsv.bgz"
#  [4] "../data/variants/ukb_wes_200k_genebass_chr12.tsv.bgz"
#  [5] "../data/variants/ukb_wes_200k_genebass_chr13.tsv.bgz"
#  [6] "../data/variants/ukb_wes_200k_genebass_chr14.tsv.bgz"
#  [7] "../data/variants/ukb_wes_200k_genebass_chr15.tsv.bgz"
#  [8] "../data/variants/ukb_wes_200k_genebass_chr16.tsv.bgz"
#  [9] "../data/variants/ukb_wes_200k_genebass_chr17.tsv.bgz"
# [10] "../data/variants/ukb_wes_200k_genebass_chr18.tsv.bgz"
# [11] "../data/variants/ukb_wes_200k_genebass_chr19.tsv.bgz"
# [12] "../data/variants/ukb_wes_200k_genebass_chr2.tsv.bgz"
# [13] "../data/variants/ukb_wes_200k_genebass_chr20.tsv.bgz"
# [14] "../data/variants/ukb_wes_200k_genebass_chr21.tsv.bgz"
# [15] "../data/variants/ukb_wes_200k_genebass_chr22.tsv.bgz"
# [16] "../data/variants/ukb_wes_200k_genebass_chr3.tsv.bgz"
# [17] "../data/variants/ukb_wes_200k_genebass_chr4.tsv.bgz"
# [18] "../data/variants/ukb_wes_200k_genebass_chr5.tsv.bgz"
# [19] "../data/variants/ukb_wes_200k_genebass_chr6.tsv.bgz"
# [20] "../data/variants/ukb_wes_200k_genebass_chr7.tsv.bgz"
# [21] "../data/variants/ukb_wes_200k_genebass_chr8.tsv.bgz"
# [22] "../data/variants/ukb_wes_200k_genebass_chr9.tsv.bgz"

# %%
# setup paths and libs
library(argparse)
library(data.table)
library(ggplot2)
library(dplyr)

#setwd('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/')

# add arguments
#parser <- ArgumentParser()
#parser$add_argument("--in_dir", default=NULL, help = "What directory should files be loaded from?")
#parser$add_argument("--in_pattern", default = 'knockouts', help = "what string should the file contains?")
#parser$add_argument("--print_input", default= FALSE, help = "print the input files headers to the terminal")
#args <- parser$parse_args()

# read in .bgz files 
zcat_fread <- function(path,...){
    cmd = paste("zcat", path)
    return(fread(cmd = cmd,...))
}


# expand hail list items. E.g. an array list A = [x,y]
# will be converted into seperate columns, A1 = x and A2 = y.
# returns the full data.frame with the new collumns appended
expand_hail_list <- function(dt, name){
    stopifnot(name %in% colnames(dt))
    x <- dt[[name]]
    x <- gsub('(\\[)|(\\])|','',x)
    mat <- do.call(rbind, strsplit(x, split = ','))
    n <- ncol(mat)
    names <- paste0(name,1:n)
    colnames(mat) <- names
    return(cbind(dt, mat))
}

files = sort(list.files('../data/variants', full.names = TRUE, pattern = 'genebass'))

pdf(outfile, width = 8, height = 7)
for (f in files[1]){
    d = zcat_fread(f)
    d = expand_hail_list(d, name = 'variant_qc.AF')
    p <- ggplot(dt, aes(x=variant_qc.AF2, y=gb_AF)) + 
    geom_bin2d(aes(fill=log10(..count..)), bins=40) + theme_classic() + 
    xlab("UK Biobank AF") + ylab("genebass AF") +
    ggtitle("UK Biobank pan-UKB AF vs. gnomAD AF after MAF matching", basename(f))
    print(p)
    p <- p + scale_x_continuous(trans='log10') + scale_y_continuous(trans='log10')
    print(p)
}
graphics.off()
# Out:
# Warning message:
# "Removed 373552 rows containing non-finite values (stat_bin2d)."
