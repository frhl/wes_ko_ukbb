# %%
setwd("/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb")
devtools::load_all("utils/modules/R/gwastools")
library(data.table)
library(pROC)
library(reshape2)
library(bigstatsr)
library(ggplot2)
library(ggrastr)
library(ggrepel)
library(ggforce)
library(ggrepel)
# Out:
# i Loading gwastools

# %%
dir = "/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb/data/prs/validation"

# %%
read_files <- function(path){
    bname <- basename(path)
    phenotype <- gsub("(ukb_eur_wes_200k_)|(_pLoF_damaging_missense.txt.gz)","",bname)
    d <- fread(path)
    d$phenotype <- phenotype
    return(d)
}

# %% [markdown]
# ## P-values without any conditioning

# %%
# read in targets
header <- fread("data/phenotypes/dec22_phenotypes_binary_200k_header.tsv", header = FALSE)$V1
targets <- paste0("ukb_eur_wes_200k_",header, "_pLoF_damaging_missense.txt.gz", sep = "")
directory <- "data/saige/output/binary/step2/min_mac4"
files <- file.path(directory, targets)
lst <- lapply(files, read_files)
d <- do.call(rbind, lst)

# %%
# tiers

# %%
d <- d[d$p.value < (0.05 / (320*2000)),]

# %%
head(d)
# Out:
#   CHR  POS MarkerID        Allele1 Allele2 AC_Allele2 AF_Allele2  MissingRate
# 1 chr1 13  ENSG00000007933 RCoW    nAsl    12         3.39776e-05 0
# 2 chr1 19  ENSG00000009709 JGMf    Xpdi     6         1.69888e-05 0
# 3 chr1 30  ENSG00000014914 fYaR    QXNf    62         1.75551e-04 0
# 4 chr1 43  ENSG00000027644 YkDw    oTNs    10         2.83147e-05 0
# 5 chr1 53  ENSG00000041988 iKje    KQJO    20         5.66293e-05 0
# 6 chr1 54  ENSG00000042781 ONNp    MqOu    38         1.07596e-04 0
#   BETA      SE       <U+22EF>   Is.SPA AF_case     AF_ctrl     N_case N_ctrl
# 1 -0.537373 1.358170 <U+22EF> FALSE  0.000000000 3.55948e-05 8023   168564
# 2 -0.549780 1.225520 <U+22EF> FALSE  0.000000000 1.77974e-05 8023   168564
# 3 -0.117885 0.463937 <U+22EF> FALSE  0.000124642 1.77974e-04 8023   168564
# 4 -0.540781 1.818570 <U+22EF> FALSE  0.000000000 2.96623e-05 8023   168564
# 5 -0.550117 0.792562 <U+22EF> FALSE  0.000000000 5.93246e-05 8023   168564
# 6 -0.547981 0.566486 <U+22EF> FALSE  0.000000000 1.12717e-04 8023   168564
#   N_case_hom N_case_het N_ctrl_hom N_ctrl_het phenotype
# 1 0          0           6         0          BC_combined
# 2 0          0           3         0          BC_combined
# 3 1          0          30         0          BC_combined
# 4 0          0           5         0          BC_combined
# 5 0          0          10         0          BC_combined
# 6 0          0          19         0          BC_combined

# %% [markdown]
# ### P-values without any conditioning

# %%
# read in targets
header <- fread("data/phenotypes/dec22_phenotypes_binary_200k_header.tsv", header = FALSE)$V1
targets <- paste0("ukb_eur_wes_200k_",header, "_pLoF_damaging_missense.txt.gz", sep = "")
directory <- "data/saige/output/binary/step2/min_mac4"
files <- file.path(directory, targets)
lst <- lapply(files, read_files)
d <- do.call(rbind, lst)

# %%
d$p.value <- as.numeric(d$p.value)
d <- d[d$p.value < (0.05 / (320*2000)),]

d_order <- d
d_order <- d_order[!d_order$phenotype %in% "spiro_undescended_testicle",]
d_order <- d_order[order(d_order$p.value),]

# %%
#options(repr.matrix.max.cols=1000, repr.matrix.max.rows=500)
options(repr.plot.width=16, repr.plot.height=8)
d_order <- d_order[d_order$AC_Allele2>=8,]
d_order <- d_order[d_order$N_case_hom>=2,]
#d_order <- d_order[1:50, ]
ggplot(d_order, aes(x=log10(d_order$AF_Allele2), y=log10(d_order$BETA), label=phenotype)) +
    geom_point(size = 2.5) +
    geom_hline(yintercept = 0, linetype = 'dashed') +
    geom_text_repel(size = 4, box.padding = 0.75, point.padding = 1.5, max.overlaps = 10, color = 'red') + 
    xlab("log10(Knockout frequency)") +
    ylab("log10(Beta)") +
    ggtitle("Top 50 significant (Tier 1 hits)") +
    theme_bw() +
    theme(
        legend.position = "bottom",
        strip.text = element_text(size=18),
        axis.text=element_text(size=16),
        axis.title=element_text(size=18,face="bold"),
        axis.title.x = element_text(margin=ggplot2::margin(t=10)),
        axis.title.y = element_text(margin=ggplot2::margin(r=10)),
        plot.title = element_text(hjust=0.5)
    )
# Out:
# Warning message:
# "ggrepel: 108 unlabeled data points (too many overlaps). Consider increasing max.overlaps"
# plot without title

# %%
list.files(dir)
# Out:
#  [1] "220712_pgs_results_bin.png"      "220712_pgs_results_bin.txt.gz"
#  [3] "220712_pgs_results_cts.png"      "220712_pgs_results_cts.txt.gz"
#  [5] "chrom"                           "chrom_qc.pdf"
#  [7] "intra_chrom_correlation_pgs.png" "ldsc_summary.txt"
#  [9] "ldsc_summary.txt.gz"             "ldsc_summary_qc_passed.txt"
# [11] "pgs_auc_summary.txt.gz"          "pgs_cor_summary.txt.gz"
# [13] "spiro_pgs_auc_summary.txt.gz"

# %%
args <- list(
    summary_ldsc = "data/prs/validation/ldsc_summary.txt.gz",
    summary_prs_cts = "data/prs/validation/pgs_cor_summary.txt.gz",
    summary_prs_bin = "data/prs/validation/spiro_pgs_auc_summary.txt.gz",
    bin_header = 'data/phenotypes/dec22_phenotypes_binary_200k_header.tsv',
    cts_header = 'data/phenotypes/filtered_phenotypes_cts_manual.tsv'
)

# %%
ldsc <- fread(args$summary_ldsc)
cts <- fread(args$summary_prs_cts)
bin <- fread(args$summary_prs_bin)

# %%
binary_header <- readLines(args$bin_header)
binary_header <- binary_header[!grepl("primary_care", binary_header)]
cts_header <- paste0(readLines(args$cts_header),"_int")

# %%
colnames(ldsc) <- paste0("ldsc_",colnames(ldsc))
#table(ldsc$ldsc_phenotype)

# %%
colnames(ldsc)[colnames(ldsc) == "ldsc_phenotype"] <- "phenotype"

# %%
# why is this only 37? These all have very low case count. I think we might have exluded them.
#length(unique(ldsc[ldsc$phenotype %in% binary_header]$phenotype))
#binary_header[!binary_header %in% ldsc[ldsc$phenotype %in% binary_header]$phenotype]

# %%
cutoff <- 0.05 / length(binary_header)

# %%
res_bin <- merge(ldsc, bin, all.x = TRUE)
res_bin <- res_bin[res_bin$phenotype %in% binary_header,]
res_cts <- merge(ldsc, cts, all.x = TRUE)
res_cts <- res_cts[res_cts$phenotype %in% cts_header,]

# %%
res_subset_bin <- res_bin[res_bin$ldsc_coef == "h2",]
res_subset_bin$pass_qc <- res_subset_bin$ldsc_pvalue < cutoff # 1e-5
res_subset_bin_phenos_pass <- res_subset_bin$phenotype[res_subset_bin$pass_qc]
res_subset_bin_phenos_pass <- as.character(res_subset_bin_phenos_pass)

# %%
res_bin$included <- ifelse(res_bin$phenotype %in% res_subset_bin_phenos_pass, 'Yes', "No")

# %%
# rename phenotypes
res_bin$phenotype <- gsub("_combined","", res_bin$phenotype)

# %%
# setup color scale
my_colors <- c("grey","#65B8EF") #"#4DBBD5B2")
names(my_colors) <- c("No","Yes")

fill_scale <- scale_fill_manual(name = "Used downstream", values = my_colors)
color_scale <- scale_color_manual(name = "Used downstream", values = my_colors)

# %%
res_order <- res_bin[res_bin$ldsc_coef == "h2"]
levels <- res_order$phenotype[order(res_order$ldsc_pvalue)]
res_bin$phenotype <- factor(res_bin$phenotype, levels = levels)

# %%
options(repr.matrix.max.rows=100, repr.matrix.max.cols=30)
#res_bin
length(unique(res_bin$phenotype))
# Out:
# [1] 294

# %%
pvalues <- res_bin[res_bin$ldsc_coef == "h2",]$ldsc_pvalue
sum(pvalues < 0.001)
# Out:
# [1] 87

# %%
res_bin <- res_bin[res_bin$ldsc_pvalue < 0.001, ]

# %%
res_bin <- res_bin[is.na(res_bin$auc_mean)]

# %%
point_size = 0.75

p1 <- ggplot(res_bin[res_bin$ldsc_coef == "h2",], 
       aes(
           y=phenotype, #reorder(phenotype, ldsc_estimate),
           x=ldsc_estimate, 
           xmax=ldsc_estimate+ldsc_std_error,
           xmin=ldsc_estimate-ldsc_std_error,
           color=included
           )
      ) + 
    geom_pointrange(size = point_size) +
    xlab(expression("LDSC" ~h^2)) + 
    ylab("Phenotypes") +
    theme_bw() +
    scale_x_continuous(breaks=scales::pretty_breaks(n=5)) +
    coord_cartesian(xlim=c(0, 1)) +
    color_scale +
    theme(
        axis.text=element_text(size=14),
        axis.title=element_text(size=14,face="bold"),
        plot.title = element_text(hjust=0.5),
        plot.subtitle = element_text(hjust=0.5),
        legend.position="none"
    ) + guides(color="none")

p2 <- ggplot(res_bin[res_bin$ldsc_coef == "intercept",], 
       aes(
           y=phenotype,
           x=ldsc_estimate, 
           xmax=ldsc_estimate+ldsc_std_error,
           xmin=ldsc_estimate-ldsc_std_error,
           color=included
           )
      ) + 
    theme_bw() +
    geom_pointrange(size = point_size) +
    xlab(expression("LDSC intercept")) + 
    geom_vline(xintercept = 1, linetype = 'dashed') +
    scale_x_continuous(breaks=scales::pretty_breaks(n=3)) + 
    color_scale +
    theme(axis.title.y=element_blank(),
        axis.text.y=element_blank(),
        axis.ticks.y=element_blank(),
        strip.text = element_text(size=16),
        axis.text=element_text(size=14),
        axis.title=element_text(size=14,face="bold"),
        plot.title = element_text(hjust=0.5),
        plot.subtitle = element_text(hjust=0.5),
        legend.position="none"
    ) + guides(color="none")

p3 <- ggplot(res_bin[res_bin$ldsc_coef == "h2",], 
       aes(
           y=phenotype, #y=reorder(phenotype, ldsc_estimate),
           x=-log10(ldsc_pvalue),
           xmax=-log10(ldsc_pvalue),
           xmin=-log10(ldsc_pvalue),
           color=included
           )
      ) + 
    geom_pointrange(size = point_size) +
    xlab(expression("LDSC"~log[10]*"(P-value)")) +
    geom_vline(xintercept = -log10(1e-5), linetype = 'dashed') +
    theme_bw() +
    color_scale +
    scale_x_continuous(breaks=scales::pretty_breaks(n=5)) +
    theme(axis.title.y=element_blank(),
        axis.text.y=element_blank(),
        axis.ticks.y=element_blank(),
        strip.text = element_text(size=16),
        axis.text=element_text(size=14),
        axis.title=element_text(size=14,face="bold"),
        plot.title = element_text(hjust=0.5),
        plot.subtitle = element_text(hjust=0.5),
        legend.position="none"
    ) + guides(color="none")

p4 <- ggplot(res_bin, 
       aes(
           y=phenotype, #y=reorder(phenotype, ldsc_estimate),
           x=auc_mean,
           xmax=auc_2_5_pct,
           xmin=auc_97_5_pct,
           color=included
           )
      ) + 
    geom_pointrange(size = point_size) +
    theme_bw() +
    color_scale +
    geom_vline(xintercept = 0.5, linetype = 'dashed') +
    xlab(expression("AUROC (95% CI)")) + 
    ylab("Phenotypes") +
    scale_x_continuous(breaks=scales::pretty_breaks(n=4)) +
    theme(axis.title.y=element_blank(),
        axis.text.y=element_blank(),
        axis.ticks.y=element_blank(),
        strip.text = element_text(size=16),
        axis.text=element_text(size=14),
        axis.title=element_text(size=14,face="bold"),
        plot.title = element_text(hjust=0.5),
        plot.subtitle = element_text(hjust=0.5),
        legend.position="none"
    ) + guides(color="none")

# %%
#ggsave("derived/plots/220908_ldpred_ldsc_summary_combined.pdf", width = 13, height = 8)
options(repr.plot.width=30, repr.plot.height=10)
cowplot::plot_grid(p1, p2, p3, p4, rel_widths = (c(0.45, 0.2, 0.2, 0.2)), ncol = 4, nrow = 1)
# Out:
# Warning message:
# "Removed 197 rows containing missing values (geom_pointrange)."
# plot without title

# %%
# Note, that PKD_combined is not shown because the estimate goes beyond the borders.

# %% [markdown]
# # PRS qq-plots

# %%
require(ggplot2)
require(ggrepel)

# %%
gwastools::

# %%
get_qq_df <- function(files){
    ribbon_p <- 0.95
    d <- do.call(rbind, lapply(files, function(f){
        stopifnot(file.exists(f))
        d <- fread(f)
        d <- d[d$AC_Allele2>=8,]
        #d <- d[d$N_case_hom>=1,]
        #KC <- d$AC_Allele2 / 2
        #KF <- d$AF_Allele2
        #case_KC <- d$N_case_hom / 2
        #ctrl_KC <- d$N_ctrl_hom / 2
        
        if (nrow(d) > 0){
            # read from conditional analysis if present
            if ("p.value_c" %in% colnames(d)) {
                d$p.value <- d$p.value_c
            }
            d$p.value.expt <- get_expected_p(d$p.value, na.rm = TRUE)
            n <- length(d$p.value)
            # create QQ
            dt <- data.table(
                ensembl_gene_id = d$MarkerID[order(d$p.value)],
                pvalue = sort(d$p.value),
                pvalue.observed = -log10(sort(d$p.value)),
                pvalue.expected = -log10(sort(d$p.value.expt)),
                clower = -log10(qbeta(p = (1 - ribbon_p) / 2, shape2 = n:1, shape1 = 1:n)),
                cupper = -log10(qbeta(p = (1 + ribbon_p) / 2, shape2 = n:1, shape1 = 1:n))
            )
            # regex the current phenotype and clean
            dt$prs <- ifelse(grepl("locoprs", f),"With PRS", "Without PRS")
            dt$analysis <- basename(f)
            dt$analysis <- stringr::str_extract(dt$analysis, "200k_.+pLoF_damaging_missense")
            dt$analysis <- gsub("200k_", "", dt$analysis)
            dt$analysis <- gsub("_pLoF_damaging_missense", "", dt$analysis)
                       
            # add hgnc and grch38 position
            dt$hgnc_symbol <- ensembl_to_hgnc[dt$ensembl_gene_id]
            dt$contig <- ensembl_to_contig[dt$ensembl_gene_id]
            dt$pos <- ensembl_to_pos[dt$ensembl_gene_id]
            #dt$KC_case <- case_KC
            #dt$KC_ctrl <- ctrl_KC
            #dt$KF <- kc$
            
            # plot label if deviated from null
            dt$label <- NA 
            bool <- dt$pvalue.observed >= dt$clower & dt$pvalue.observed > 3
            dt$label[bool] <- dt$hgnc_symbol[bool]
            
 
        return(dt)
        } else {
            return(NULL)
        }
    }))
    return(d)
}

# %%
# map from ENSEMBL to HGNC
bridge <- fread("/well/lindgren/flassen/ressources/genesets/genesets/data/biomart/220524_hgnc_ensg_enst_chr_pos.txt.gz")
ensembl_to_hgnc <- bridge$hgnc_symbol
names(ensembl_to_hgnc) <- bridge$ensembl_gene_id
ensembl_to_pos <- (bridge$start_position + bridge$end_position)/2
names(ensembl_to_pos) <- bridge$ensembl_gene_id
ensembl_to_contig <- bridge$chromosome_name
names(ensembl_to_contig) <- bridge$ensembl_gene_id

# %%
#pattern <- "ukb_eur_wes_200k_maf0to5e-2.+txt.gz"
#files <- list.files("data/saige/output/binary/step2/min_mac4/", pattern = pattern, full.names = TRUE)
#files <- files[!grepl("primary_care",files)]

header <- fread("data/phenotypes/dec22_phenotypes_binary_200k_header.tsv", header = FALSE)$V1
targets <- paste0("ukb_eur_wes_200k_",header, "_pLoF_damaging_missense.txt.gz", sep = "")
targets_prs <- paste0("ukb_eur_wes_200k_",header, "_pLoF_damaging_missense_locoprs.txt.gz", sep = "")
directory <- "data/saige/output/binary/step2/min_mac4"
files <- file.path(directory, targets)
files_prs <- file.path(directory, targets_prs)
files_prs <- unlist(lapply(files_prs, function(f) f[file.exists(f)]))

# %%
d1 <- get_qq_df(files)
d1$analysis <- factor(d1$analysis, levels = unique(d1$analysis))

# %%
d2 <- get_qq_df(files_prs)
d2$analysis <- factor(d2$analysis, levels = unique(d2$analysis))

# %%
d <- rbind(d1, d2)

# %%
# setup color scale
my_colors <- c("#CC6666","#65B8EF") #c("#7BA98A","#65B8EF")
names(my_colors) <- c("Without PRS", "With PRS")
fill_scale <- scale_fill_manual(name = "prs", values = my_colors)
color_scale <- scale_color_manual(name = "prs", values = my_colors)

# %%
options(repr.plot.width=18, repr.plot.height=15)
ggplot(d, aes(x=pvalue.expected, y=pvalue.observed, ymax=cupper, ymin=clower, label = label, color=prs)) +
    geom_ribbon(fill="grey80", color="black", alpha = 0.7, linetype = 'dashed') +
    geom_point(size = 0.75) +
    geom_abline(linetype = 'dotted') + 
    scale_x_continuous(breaks=scales::pretty_breaks(n=5)) +
    scale_y_continuous(breaks=scales::pretty_breaks(n=5)) +
    xlab(expression(paste(-log[10],'(Expected P-value)' ))) +
    ylab(expression(paste(-log[10],'(Observed P-value)' ))) +
    color_scale +
    #geom_label_repel(
    #    box.padding = 0.4, label.padding=0.1, point.padding = 0.2,
    #    color = 'grey30', segment.color = 'grey50', max.overlaps=Inf,
    #    size=2, segment.size=0.1, show.legend = FALSE
    #) +
    facet_wrap_paginate(~analysis, nrow = 7, ncol = 7, page = 1, scales = "free_y") +
    theme_bw() + 
    theme(
        strip.text = element_text(size=16),
        axis.text=element_text(size=14),
        axis.title=element_text(size=12,face="bold"),
        axis.title.x = element_text(margin=ggplot2::margin(t=16)),
        axis.title.y = element_text(margin=ggplot2::margin(r=16)),
        plot.title = element_text(hjust=0.5),
        plot.subtitle = element_text(hjust=0.5),
        legend.position="top"
    )
# Out:
# plot without title

# %%
dt <- as.data.table(table(d$analysis, d$prs))
traits_with_prs <- dt$V1[(dt$V2 == "With PRS") & (dt$N != 0)]

# %%
d_with_prs <- d[(d$analysis %in% traits_with_prs) & (d$prs == "With PRS"),]
d_without_prs <- d[(!d$analysis %in% traits_with_prs) & (d$prs == "Without PRS"),]
d_final <- rbind(d_with_prs, d_without_prs)

# %%
# Out:
#    With PRS Without PRS
#       71622      284102

# %%
test <- d_final[d_final$pvalue.observed > -log10(0.05 / (315 * 20000)),]
test[rev(order(test$pvalue.observed)),]
#test[test$prs == "With PRS",]
# Out:
#        ensembl_gene_id pvalue        pvalue.observed pvalue.expected clower
# 1      ENSG00000126259 2.788997e-171 170.55455       3.059563        4.655763
# 2      ENSG00000137198  5.654232e-89  88.24763       3.059563        4.655763
# 3      ENSG00000152242  5.062624e-84  83.29562       3.059563        4.655763
# 4      ENSG00000124006  1.643912e-63  62.78412       2.758533        3.674850
# 5      ENSG00000175564  2.378300e-60  59.62373       3.059563        4.655763
# 6      ENSG00000183765  6.155778e-57  56.21072       3.059563        4.655763
# 7      ENSG00000143126  2.711438e-55  54.56680       3.059563        4.655763
# 8      ENSG00000181333  4.578155e-50  49.33931       3.059563        4.655763
# 9      ENSG00000132781  2.450727e-48  47.61071       3.033424        4.629600
# 10     ENSG00000166596  1.799310e-46  45.74489       3.059563        4.655763
# 11     ENSG00000076242  2.620168e-46  45.58167       2.758533        3.674850
# 12     ENSG00000167065  2.847438e-46  45.54555       3.059563        4.655763
# 13     ENSG00000133863  4.101772e-46  45.38703       3.059563        4.655763
# 14     ENSG00000065600  1.748264e-45  44.75739       2.758533        3.674850
# 15     ENSG00000183765  4.048305e-45  44.39273       3.059563        4.655763
# 16     ENSG00000141012  5.394948e-44  43.26801       2.582442        3.267462
# 17     ENSG00000172992  6.913030e-44  43.16033       3.059563        4.655763
# 18     ENSG00000206072  7.840890e-44  43.10563       3.059563        4.655763
# 19     ENSG00000138459  2.469013e-43  42.60748       3.059563        4.655763
# 20     ENSG00000108839  2.468042e-42  41.60765       2.758533        3.674850
# 21     ENSG00000141756  1.432708e-41  40.84384       2.582442        3.267462
# 22     ENSG00000132781  3.527419e-40  39.45254       3.059563        4.655763
# 23     ENSG00000213614  4.311958e-40  39.36533       3.059563        4.655763
# 24     ENSG00000196860  1.212005e-39  38.91650       3.059563        4.655763
# 25     ENSG00000159307  1.416868e-39  38.84867       2.457503        3.021449
# 26     ENSG00000117480  1.998370e-39  38.69932       3.059563        4.655763
# 27     ENSG00000145703  3.106067e-39  38.50779       2.758533        3.674850
# 28     ENSG00000121417  6.037773e-39  38.21912       2.758533        3.674850
# 29     ENSG00000272514  2.805263e-37  36.55203       2.582442        3.021449
# 30     ENSG00000213204  2.805263e-37  36.55203       2.582442        3.267462
# <U+22EE> <U+22EE>        <U+22EE>      <U+22EE>        <U+22EE>        <U+22EE>
# 581    ENSG00000114455 4.289899e-09  8.367553        2.018171        2.318664
# 582    ENSG00000068976 4.296127e-09  8.366923        2.457503        3.021449
# 583    ENSG00000168356 4.298510e-09  8.366682        1.913435        2.174283
# 584    ENSG00000272514 4.407119e-09  8.355845        1.980382        2.217991
# 585    ENSG00000213204 4.407119e-09  8.355845        1.980382        2.265840
# 586    ENSG00000257093 4.415007e-09  8.355069        2.094588        2.433276
# 587    ENSG00000129317 4.429831e-09  8.353613        1.980382        2.265840
# 588    ENSG00000006747 4.451114e-09  8.351531        2.018171        2.318664
# 589    ENSG00000171502 4.582690e-09  8.338880        2.059563        2.377562
# 590    ENSG00000103222 4.597047e-09  8.337521        1.903865        2.164682
# 591    ENSG00000141568 4.751152e-09  8.323201        2.105321        2.444038
# 592    ENSG00000144285 4.881961e-09  8.311406        1.980382        2.265840
# 593    ENSG00000141756 4.924235e-09  8.307661        2.281412        2.715857
# 594    ENSG00000145113 5.235512e-09  8.281041        2.214465        2.609200
# 595    ENSG00000250120 5.278285e-09  8.277507        2.156473        2.520210
# 596    ENSG00000106571 5.344988e-09  8.272053        2.105321        2.444038
# 597    ENSG00000117115 5.610000e-09  8.251037        2.281412        2.715857
# 598    ENSG00000123454 5.707822e-09  8.243530        1.855443        2.096869
# 599    ENSG00000128310 5.832325e-09  8.234158        2.457503        3.021449
# 600    ENSG00000206190 5.872490e-09  8.231178        2.582442        3.267462
# 601    ENSG00000179862 6.131896e-09  8.212405        2.281412        2.715857
# 602    ENSG00000168702 6.364993e-09  8.196202        2.105321        2.444038
# 603    ENSG00000165695 6.378845e-09  8.195258        2.105321        2.444038
# 604    ENSG00000135953 6.786425e-09  8.168359        1.980382        2.265840
# 605    ENSG00000106571 6.868114e-09  8.163163        2.156473        2.520210
# 606    ENSG00000176978 6.881573e-09  8.162312        1.873902        2.124475
# 607    ENSG00000166535 7.103698e-09  8.148516        2.360593        2.848285
# 608    ENSG00000156049 7.488479e-09  8.125606        2.758533        3.674850
# 609    ENSG00000072778 7.537542e-09  8.122770        2.457503        3.021449
# 610    ENSG00000241404 7.685386e-09  8.114334        1.845873        2.087265
#        cupper   prs
# 1      2.492989 Without PRS
# 2      2.492989 Without PRS
# 3      2.492989 Without PRS
# 4      2.314067 Without PRS
# 5      2.492989 Without PRS
# 6      2.492989 Without PRS
# 7      2.492989 Without PRS
# 8      2.492989 Without PRS
# 9      2.466869 With PRS
# 10     2.492989 Without PRS
# 11     2.314067 Without PRS
# 12     2.492989 Without PRS
# 13     2.492989 Without PRS
# 14     2.314067 Without PRS
# 15     2.492989 Without PRS
# 16     2.201356 Without PRS
# 17     2.492989 Without PRS
# 18     2.492989 Without PRS
# 19     2.492989 Without PRS
# 20     2.314067 Without PRS
# 21     2.201356 Without PRS
# 22     2.492989 Without PRS
# 23     2.492989 Without PRS
# 24     2.492989 Without PRS
# 25     2.117413 Without PRS
# 26     2.492989 Without PRS
# 27     2.314067 Without PRS
# 28     2.314067 Without PRS
# 29     2.117413 Without PRS
# 30     2.201356 Without PRS
# <U+22EE> <U+22EE> <U+22EE>
# 581    1.796187 Without PRS
# 582    2.117413 Without PRS
# 583    1.713990 Without PRS
# 584    1.739462 Without PRS
# 585    1.766762 Without PRS
# 586    1.852307 Without PRS
# 587    1.766762 Without PRS
# 588    1.796187 Without PRS
# 589    1.828108 Without PRS
# 590    1.704450 Without PRS
# 591    1.863013 Without PRS
# 592    1.766762 Without PRS
# 593    1.993440 Without PRS
# 594    1.944597 Without PRS
# 595    1.901546 Without PRS
# 596    1.863013 Without PRS
# 597    1.993440 Without PRS
# 598    1.667631 Without PRS
# 599    2.117413 Without PRS
# 600    2.201356 Without PRS
# 601    1.993440 Without PRS
# 602    1.863013 Without PRS
# 603    1.863013 Without PRS
# 604    1.766762 Without PRS
# 605    1.901546 Without PRS
# 606    1.680572 Without PRS
# 607    2.050000 Without PRS
# 608    2.314067 Without PRS
# 609    2.117413 Without PRS
# 610    1.658093 Without PRS
#        analysis                                                  hgnc_symbol
# 1      spiro_polycystic_ovarian_syndrome                         KIRREL2
# 2      spiro_intellectual_disability                             GMPR
# 3      spiro_parasitic_infections                                C18orf25
# 4      spiro_intellectual_disability                             OBSL1
# 5      spiro_tuberculosis                                        UCP3
# 6      spiro_leukaemia                                           CHEK2
# 7      spiro_motor_neuron_disease                                CELSR2
# 8      spiro_dementia                                            HEPHL1
# 9      CC_combined                                               MUTYH
# 10     spiro_secondary_malignancy_pleura                         CFAP52
# 11     spiro_polycystic_ovarian_syndrome                         MLH1
# 12     spiro_secondary_malignancy_bowel                          DUSP18
# 13     spiro_collapsed_vertebra                                  TEX15
# 14     spiro_parasitic_infections                                PACC1
# 15     spiro_myelodysplastic_syndromes                           CHEK2
# 16     spiro_intellectual_disability                             GALNS
# 17     spiro_polycythaemia_vera                                  DCAKD
# 18     spiro_primary_malignancy_cervical                         SERPINB11
# 19     spiro_other_interstitial_pulmonary_diseases_with_fibrosis SLC35A5
# 20     spiro_motor_neuron_disease                                ALOX12
# 21     spiro_polycystic_ovarian_syndrome                         FKBP10
# 22     spiro_primary_malignancy_colorectal_and_anus              MUTYH
# 23     spiro_other_cardiomyopathy                                HEXA
# 24     spiro_primary_malignancy_pancreatic                       TOMM20L
# 25     spiro_intellectual_disability                             SCUBE1
# 26     DEM_combined                                              FAAH
# 27     spiro_secondary_malignancy_pleura                         IQGAP2
# 28     spiro_leukaemia                                           ZNF211
# 29     spiro_motor_neuron_disease                                CFAP206
# 30     spiro_motor_neuron_disease
# <U+22EE> <U+22EE>                                                  <U+22EE>
# 581    spiro_parkinsons_disease                                  HHLA2
# 582    spiro_bronchiectasis                                      PYGM
# 583    spiro_abdominal_aortic_aneurysm                           SCN11A
# 584    INF_combined                                              CFAP206
# 585    INF_combined
# 586    DM_GD                                                     DENND11
# 587    spiro_parkinsons_disease                                  PUS7L
# 588    spiro_hypertrophy_of_nasal_turbinates                     SCIN
# 589    spiro_sick_sinus_syndrome                                 COL24A1
# 590    DM_T1D                                                    ABCC1
# 591    spiro_secondary_malignancy_bone                           FOXK2
# 592    spiro_liver_fibrosis_sclerosis_and_cirrhosis              SCN1A
# 593    spiro_female_infertility                                  FKBP10
# 594    spiro_end_stage_renal_disease                             MUC4
# 595    spiro_scleritis_and_episcleritis                          PCDHA10
# 596    spiro_pleural_plaque                                      GLI3
# 597    spiro_pulmonary_collapse                                  PADI2
# 598    spiro_leukaemia                                           DBH
# 599    AD_combined                                               GALR3
# 600    spiro_obstructive_and_reflux_uropathy                     ATP10A
# 601    spiro_visual_impairment_and_blindness                     CITED4
# 602    spiro_sjogrens_disease                                    LRP1B
# 603    spiro_crohns_disease                                      AK8
# 604    spiro_primary_malignancy_oesophageal                      MFSD9
# 605    spiro_essential_tremor                                    GLI3
# 606    DM_T1D                                                    DPP7
# 607    spiro_bronchiectasis                                      A2ML1
# 608    spiro_spinal_stenosis                                     GNA14
# 609    spiro_nonrheumatic_aortic_valve_disorders                 ACADVL
# 610    DM_T1D                                                    EGFL8
#        contig pos       label
# 1      19      35861498 KIRREL2
# 2      6       16267068 GMPR
# 3      18      46220272 C18orf25
# 4      2      219561294 OBSL1
# 5      11      74004681 UCP3
# 6      22      28715082 CHEK2
# 7      1      109262645 CELSR2
# 8      11      94067781 HEPHL1
# 9      1       45335028 MUTYH
# 10     17       9610037 CFAP52
# 11     3       37022098 MLH1
# 12     22      30659969 DUSP18
# 13     8       30872276 TEX15
# 14     1      212389414 PACC1
# 15     22      28715082 CHEK2
# 16     16      88835352 GALNS
# 17     17      45042234 DCAKD
# 18     18      63687006 SERPINB11
# 19     3      112573644 SLC35A5
# 20     17       7003402 ALOX12
# 21     17      41817946 FKBP10
# 22     1       45335028 MUTYH
# 23     15      72358672 HEXA
# 24     14      58402315 TOMM20L
# 25     22      43270326 SCUBE1
# 26     1       46404082 FAAH
# 27     5       76555708 IQGAP2
# 28     19      57637218 ZNF211
# 29     6       87436218 CFAP206
# 30     6       87459823
# <U+22EE> <U+22EE> <U+22EE>  <U+22EE>
# 581    3      108337388 HHLA2
# 582    11      64753182 PYGM
# 583    3       38948960 SCN11A
# 584    6       87436218 CFAP206
# 585    6       87459823
# 586    7      141679447 DENND11
# 587    12      43738892 PUS7L
# 588    7       12615380 SCIN
# 589    1       85943088 COL24A1
# 590    16      16046198 ABCC1
# 591    17      82582188 FOXK2
# 592    2      166066928 SCN1A
# 593    17      41817946 FKBP10
# 594    3      195779369 MUC4
# 595    5      140934115 PCDHA10
# 596    7       42112524 GLI3
# 597    1       17093106 PADI2
# 598    9      133647846 DBH
# 599    22      37824434 GALR3
# 600    15      25771228 ATP10A
# 601    1       40861708 CITED4
# 602    2      141181220 LRP1B
# 603    9      132802178 AK8
# 604    2      102725759 MFSD9
# 605    7       42112524 GLI3
# 606    9      137112862 DPP7
# 607    12       8854811 A2ML1
# 608    9       77535700 GNA14
# 609    17       7221196 ACADVL
# 610    6       32166438 EGFL8

# %%
d <- fread("data/conditional/common/spa_iter/ukb_eur_wes_200k_spiro_polycystic_ovarian_syndrome_pLoF_damaging_missense_cond_i1_chr19")

# %%
head(d)
# Out:
#   CHR   POS    MarkerID    Allele1 Allele2 AC_Allele2 AF_Allele2 MissingRate
# 1 chr19 397111 rs7408940   C       G       100140     0.2835430  0.00181780
# 2 chr19 397313 rs72988434  A       T        88010     0.2491970  0.00182346
# 3 chr19 397772 rs7343106   T       C        88109     0.2494780  0.00181780
# 4 chr19 397896 rs17672491  C       T         9208     0.0260721  0.00181780
# 5 chr19 398477 rs3926400   C       T       151947     0.4302330  0.00181780
# 6 chr19 398513 rs566537746 C       T         9432     0.0267064  0.00181780
#   BETA       SE        Tstat    var      p.value   p.value.NA Is.SPA AF_case
# 1  0.0162689 0.0910864  1.96088 120.5290 0.8582445 0.8582445  FALSE  0.2838280
# 2  0.0358142 0.0950827  3.96143 110.6110 0.7064236 0.7064236  FALSE  0.2541250
# 3  0.0350932 0.0950729  3.88249 110.6330 0.7120387 0.7120387  FALSE  0.2541250
# 4 -0.1806090 0.2579820 -2.71368  15.0252 0.4838760 0.4838760  FALSE  0.0214521
# 5  0.1029030 0.0824748 15.12810 147.0140 0.2121451 0.2121451  FALSE  0.4521450
# 6 -0.1743980 0.2504000 -2.78145  15.9489 0.4861310 0.4861310  FALSE  0.0231023
#   AF_ctrl   N_case N_ctrl
# 1 0.2835420 303    176284
# 2 0.2491890 303    176284
# 3 0.2494700 303    176284
# 4 0.0260801 303    176284
# 5 0.4301950 303    176284
# 6 0.0267126 303    176284

# %%
# mapping bridge
bridge <- fread("/well/lindgren/flassen/ressources/genesets/genesets/data/biomart/220524_hgnc_ensg_enst_chr_pos.txt.gz")
ensembl_to_hgnc <- bridge$ensembl_gene_id
names(ensembl_to_hgnc) <- bridge$hgnc_symbol

# %%
args <- list(
    coordinates = "data/genes/220310_ensgid_grch38_pos.tsv.gz",
    genes = "data/conditional/common/gene_positions/min_mac4/ukb_eur_wes_200k_spiro_polycystic_ovarian_syndrome_pLoF_damaging_missense.tsv.gz"
)

# %%
d_clust <- data.frame(pos=d$POS, k=rank(d$POS))
fit <- kmeans(d_clust, nrow(genes))
d$cluster <- fit$cluster

# %%
is_overlapping <- function(x1,x2,y1,y2){
    return(max(x1,y1) <= min(x2,y2))
    }

which_overlap <- function(x1, x2, y1, y2){
    nx <- nrow(x)
    ny <- nrow(y)
    index <- unlist(lapply(1:nx, function(i){
        index <- which(unlist(lapply(1:ny, function(j){
            x1i <- x1[i]
            x2i <- x2[i]
            y1j <- y1[j]
            y2j <- y2[j]
            stopifnot(x1i < x2i)
            stopifnot(y1j < y2j)
            overlap <- is_overlapping(x1i, x2i, y1j, y2j)
        })))
        return(unlist(index))
    }))
    return(index)
    }

# %%
boundary_max <- aggregate(POS ~ cluster , FUN=max, data=d)
boundary_min <- aggregate(POS ~ cluster , FUN=min, data=d)
boundary_variants <- aggregate(POS ~ cluster , FUN=length, data=d)
colnames(boundary_max)[2] <- "upper"
colnames(boundary_min)[2] <- "lower"
colnames(boundary_variants)[2] <- "variants"

# %%
full <- Reduce(merge, list(boundary_max, boundary_min, boundary_variants))
full$ensembl_gene_id <- genes$gene[which_overlap(genes$start, genes$end, full$lower, full$upper)]
full$hgnc_symbol <- ensembl_to_hgnc[full$ensembl_gene_id]

# %%
ensembl_to_hgnc

# %%
x <- genes
y <- full

# %%
ranges_x <-

# %%
is_overlapping(gene$start, gene$end, mrg$lower, mrg$upper)
# Out:
#   gene            pvalue        contig start    end
# 1 ENSG00000126259 2.788997e-171 19     35855861 35867136
#   cluster upper    lower    variants
# 1 1       44205911 42192883 6523
# [1] FALSE

# %%
gene$start < gene$end
mrg$lower < mrg$upper
# Out:
# [1] TRUE
# [1] FALSE

# %%
# Out:
#   cluster upper    lower    variants
# 5 5       16022766 16022766 7239

# %%
coord <- fread(args$coordinates)
genes <- fread(args$genes)
genes <- genes[genes$contig == 19,]
genes$start < genes$end
# Out:
# [1] TRUE TRUE TRUE TRUE TRUE

# %%
plot(y=-log10(d$p.value), x=d$POS, col = d$cluster)
#for (i in 1:nrow(genes)) points(x=seq(genes$start[i]-1e5, genes$end[i]+1e5, length.out=100), y=rep(1.1, 100))
#text(x=genes$start, y=1.12, labels = genes$gene, cex = 0.8)
# Out:
# plot without title
