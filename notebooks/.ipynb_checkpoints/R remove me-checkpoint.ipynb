# %%
setwd('/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb')
library(data.table)

# %%
d_ac <- fread("data/conditional/rare/combined/ukb_eur_wes_200k_chr15_maf0to5e-2_pLoF_damaging_missense_AC.txt.gz")
d_hash <- fread("data/conditional/rare/combined/ukb_eur_wes_200k_chr15_maf0to5e-2_pLoF_damaging_missense_hash.txt.gz")

# %%
vcf_path <- "data/conditional/rare/combined/ukb_eur_wes_200k_chr15_maf0to5e-2_pLoF_damaging_missense.vcf.bgz"
cmd <- paste("zcat",vcf_path,"| grep -v '##' | cut -f3")
d <- fread(cmd = cmd)

# %%
phenotype <- "BC_combined_primary_care"

# %%
vcf_markers <- d$ID[grepl("chr",d$ID)]
ac_markers <- d_ac$id[d_ac[[phenotype]] >= 4]

# %%
markers <- intersect(vcf_markers, ac_markers)

# %%
d_hash_subset <- d_hash[d_hash$id %in% markers,]
dups <- duplicated(d_hash_subset[[phenotype]])
d_hash_subset <- d_hash_subset[!dups, ]
hash_markers <- d_hash_subset$id

# %%
final_markers <- intersect(markers, hash_markers)

# %%
ord <- order(final_markers)

# %%
head(final_markers[ord]); head(final_markers)
# Out:
# [1] "chr15:100048888:G:A"  "chr15:100051578:C:T"  "chr15:100096364:C:CG"
# [4] "chr15:100096382:C:T"  "chr15:100096467:A:G"  "chr15:100109000:C:T"
# [1] "chr15:22883001:A:T" "chr15:22909192:A:G" "chr15:22943171:A:T"
# [4] "chr15:22944890:C:T" "chr15:23004107:C:A" "chr15:23009944:C:T"

# %%
lst <- lapply(strsplit(final_markers, split = ':'), function(x) as.numeric(x[2]))

# %%
ac <- d_ac[[phenotype]][d_ac$id %in% final_markers]

# %%
all(ac == round(ac))
# Out:
# [1] TRUE

# %%
length(final_markers)
# Out:
# [1] 6775

# %%
m <- fread("data/mt/vep/ukb_eur_wes_200k_csqs_chr15.tsv.gz")

# %%
args <- list(
    p_cutoff = 5e-6,
    vep_path_with_CHR = "data/mt/vep/ukb_eur_wes_200k_csqs_chrCHR.tsv.gz",
    in_spa_file = "data/saige/output/binary/step2/min_mac4/ukb_eur_wes_200k_maf0to5e-2_CC_combined_pLoF_damaging_missense_locoprs.txt.gz"
)

# %%
spa <- fread(args$in_spa_file)
spa_n <- nrow(spa)

# %%
p_cutoff <- as.numeric(args$p_cutoff)
spa <- spa[spa$p.value < p_cutoff,]
chromsomes <- gsub("chr", "", unique(spa$CHR))

for (chr in chromsomes){
    
    vep_path <- gsub("CHR", chr, args$vep_path_with_CHR)
    stopifnot(file.exists(vep_path))
    vep <- fread(vep_path)
    
    
}

# %%
vep$
# Out:
#   locus       alleles        rsid info.AC info.AF    info.AN MAF        MAC
# 1 chr1:925908 ["G","GGCTCT"] NA   9       2.5436e-05 353830  2.5436e-05 9
# 2 chr1:925908 ["G","GGCTCT"] NA   9       2.5436e-05 353830  2.5436e-05 9
# 3 chr1:925912 ["C","G"]      NA   4       1.1305e-05 353830  1.1305e-05 4
# 4 chr1:925912 ["C","G"]      NA   4       1.1305e-05 353830  1.1305e-05 4
# 5 chr1:925913 ["T","G"]      NA   3       8.4786e-06 353830  8.4786e-06 3
# 6 chr1:925913 ["T","G"]      NA   3       8.4786e-06 353830  8.4786e-06 3
#   varid                csqs.allele_num <U+22EF>   csqs.swissprot
# 1 chr1:925908:G:GGCTCT 1               <U+22EF> NA
# 2 chr1:925908:G:GGCTCT 1               <U+22EF> NA
# 3 chr1:925912:C:G      1               <U+22EF> NA
# 4 chr1:925912:C:G      1               <U+22EF> NA
# 5 chr1:925913:T:G      1               <U+22EF> NA
# 6 chr1:925913:T:G      1               <U+22EF> NA
#   csqs.transcript_id csqs.trembl csqs.uniparc csqs.variant_allele
# 1 ENST00000342066    NA          NA           GCTCT
# 2 ENST00000609207    NA          NA           GCTCT
# 3 ENST00000342066    NA          NA           G
# 4 ENST00000609207    NA          NA           G
# 5 ENST00000342066    NA          NA           G
# 6 ENST00000609207    NA          NA           G
#   csqs.revel_score csqs.cadd_phred csqs.most_severe_consequence csqs.csq_score
# 1 NA               NA              intron_variant               24
# 2 NA               NA              upstream_gene_variant        28
# 3 NA               NA              intron_variant               24
# 4 NA               NA              upstream_gene_variant        28
# 5 NA               NA              intron_variant               24
# 6 NA               NA              upstream_gene_variant        28
#   consequence_category
# 1 non_coding
# 2 non_coding
# 3 non_coding
# 4 non_coding
# 5 non_coding
# 6 non_coding

# %%
out <- data.table(
    gene = gsub("\\..+$",'',mrg$ensembl_gene_id),
    pvalue = mrg$p.value,
    contig = mrg$chromosome_name,
    start = mrg$start_position - as.numeric(args$flanking_bp),
    end = mrg$end_position + as.numeric(args$flanking_bp)
 )

# filter to signifcant entries


n <- nrow(out)
msg <- paste("Subsetted", args$phenotype, "to", n, "significant entries in", args$in_spa_file)
write(msg, stdout())


if (n > 0){
    outfile = paste0(args$out_prefix, '.tsv.gz')
    write(paste("writing to", outfile), stderr())
    fwrite(out, outfile, sep = '\t')
}
# Out:
#   locus       alleles   rsid info.AC info.AF    info.AN MAF        MAC
# 1 chr8:240846 ["T","C"] NA   1       2.8311e-06 353224  2.8311e-06 1
# 2 chr8:240846 ["T","C"] NA   1       2.8311e-06 353224  2.8311e-06 1
# 3 chr8:240849 ["T","C"] NA   1       2.8294e-06 353430  2.8294e-06 1
# 4 chr8:240849 ["T","C"] NA   1       2.8294e-06 353430  2.8294e-06 1
# 5 chr8:240850 ["G","C"] NA   1       2.8302e-06 353330  2.8302e-06 1
# 6 chr8:240850 ["G","C"] NA   1       2.8302e-06 353330  2.8302e-06 1
#   varid           csqs.allele_num <U+22EF>   csqs.swissprot csqs.transcript_id
# 1 chr8:240846:T:C 1               <U+22EF> NA             ENST00000398612
# 2 chr8:240846:T:C 1               <U+22EF> NA             ENST00000610248
# 3 chr8:240849:T:C 1               <U+22EF> NA             ENST00000398612
# 4 chr8:240849:T:C 1               <U+22EF> NA             ENST00000610248
# 5 chr8:240850:G:C 1               <U+22EF> NA             ENST00000398612
# 6 chr8:240850:G:C 1               <U+22EF> NA             ENST00000610248
#   csqs.trembl csqs.uniparc csqs.variant_allele csqs.revel_score csqs.cadd_phred
# 1 NA          NA           C                   NA               NA
# 2 NA          NA           C                   NA               NA
# 3 NA          NA           C                   NA               NA
# 4 NA          NA           C                   NA               NA
# 5 NA          NA           C                   NA               NA
# 6 NA          NA           C                   NA               NA
#   csqs.most_severe_consequence csqs.csq_score consequence_category
# 1 5_prime_UTR_variant          20             non_coding
# 2 downstream_gene_variant      29             non_coding
# 3 5_prime_UTR_variant          20             non_coding
# 4 downstream_gene_variant      29             non_coding
# 5 5_prime_UTR_variant          20             non_coding
# 6 downstream_gene_variant      29             non_coding
