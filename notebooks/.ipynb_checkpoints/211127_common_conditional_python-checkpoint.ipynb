# %%
import hail as hl
import os
import pandas as pd
from ukb_utils import hail_init
from ukb_utils import genotypes
from ukb_utils import samples
from ukb_utils import variants
from ko_utils import qc
from ko_utils import analysis

# %%
os.chdir('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/')
hail_init.hail_bmrc_init('logs/hail/hail_test_export.log', 'GRCh38')
# Out:
# Running on Apache Spark version 3.1.2
# SparkUI available at http://compa019.hpc.in.bmrc.ox.ac.uk:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.77-684f32d73643
# LOGGING: writing to logs/hail/hail_test_export.log

# %%
PATH_GENE_INTERVALS = 'derived/tables/gene_intervals/211111_wes200k_saige_wes_saige_sig_genes_intervals.txt'
PHENOTYPE = 'breast_cancer'

# %%
ht = hl.import_table(PATH_GENE_INTERVALS, force_bgz = True, delimiter = '\t', missing = '',
                     types={'contig': hl.tstr,'start': hl.tint, 'end': hl.tint, 'contig_length': hl.tint}) 
ht = ht.annotate(contig = hl.delimit(['chr',ht.contig],''))
# Out:
# 2021-11-29 20:35:37 Hail: INFO: Reading table without type imputation
#   Loading field 'gene' as type str (not specified)
#   Loading field 'FDR' as type str (not specified)
#   Loading field 'maf' as type str (not specified)
#   Loading field 'mutation' as type str (not specified)
#   Loading field 'phenotype' as type str (not specified)
#   Loading field 'contig' as type str (user-supplied)
#   Loading field 'start' as type int32 (user-supplied)
#   Loading field 'end' as type int32 (user-supplied)
#   Loading field 'contig_length' as type int32 (user-supplied)

# %%
padding = 500000
ht = ht.annotate(ranges = hl.array([ht.start,ht.end]))
ht = ht.annotate(
    end = hl.max(ht.ranges),
    start = hl.min(ht.ranges))
ht = ht.annotate(
    end_with_padding = hl.min(hl.array([ht.end + padding, ht.contig_length])),
    start_with_padding = hl.max(hl.array([ht.start - padding, 1])))
ht = ht.drop(ht.ranges)
ht.head(5).show()
# Out:
# +-------------------+----------------------+---------+----------+-----------------------------------------+---------+----------+----------+---------------+------------------+--------------------+
# | gene              | FDR                  | maf     | mutation | phenotype                               | contig  |    start |      end | contig_length | end_with_padding | start_with_padding |
# +-------------------+----------------------+---------+----------+-----------------------------------------+---------+----------+----------+---------------+------------------+--------------------+
# | str               | str                  | str     | str      | str                                     | str     |    int32 |    int32 |         int32 |            int32 |              int32 |
# +-------------------+----------------------+---------+----------+-----------------------------------------+---------+----------+----------+---------------+------------------+--------------------+
# | "ENSG00000136297" | "0.0795317615353971" | "00_01" | "ptv"    | "coronary_artery_disease"               | "chr7"  |  4905989 |  4959213 |     159345973 |          5459213 |            4405989 |
# | "ENSG00000188611" | "0.0795317615353971" | "00_01" | "ptv"    | "coronary_artery_disease"               | "chr10" | 50182778 | 50279720 |     133797422 |         50779720 |           49682778 |
# | "ENSG00000105501" | "0"                  | "00_01" | "ptv"    | "chronic_obstructive_pulmonary_disease" | "chr19" | 51611927 | 51645545 |      58617616 |         52145545 |           51111927 |
# | "ENSG00000178460" | "0"                  | "00_01" | "ptv"    | "chronic_obstructive_pulmonary_disease" | "chr8"  | 66870749 | 66922048 |     145138636 |         67422048 |           66370749 |
# | "ENSG00000187546" | "0"                  | "00_01" | "ptv"    | "chronic_obstructive_pulmonary_disease" | "chr7"  | 15200317 | 15562015 |     159345973 |         16062015 |           14700317 |
# +-------------------+----------------------+---------+----------+-----------------------------------------+---------+----------+----------+---------------+------------------+--------------------+

# %%
reference_genome = 'GRCh38'
ht = ht.annotate(start_valid = hl.is_valid_locus(ht.contig, ht.start, reference_genome))
ht = ht.annotate(end_valid = hl.is_valid_locus(ht.contig, ht.end, reference_genome))
ht = ht.annotate(valid_intervals = ht.start_valid & ht.end_valid)
defined_coords = hl.is_defined(ht.valid_intervals)
n_drop = ht.filter(~defined_coords).count()
if n_drop > 0:
    print(f'Dropping {n_drop} undefined start/end genomic coordinates.')
    ht = ht.filter(defined_coords)
invalid_intervals = ht.filter(~ht.valid_intervals).count()
assert invalid_intervals == 0, 'Some of the supplied intervals are outside current chromosome contig'
ht = ht.annotate(intervals = hl.locus_interval(ht.contig, ht.start, ht.end, True, True, reference_genome=reference_genome))
# Out:
# Dropping 1 undefined start/end genomic coordinates.

# %%
ht = ht.filter(ht.phenotype == PHENOTYPE)

# %%
ht.show()
# Out:
# +-------------------+----------------------+---------+-------------------------+-----------------+---------+-----------+-----------+---------------+------------------+--------------------+-------------+-----------+-----------------+
# | gene              | FDR                  | maf     | mutation                | phenotype       | contig  |     start |       end | contig_length | end_with_padding | start_with_padding | start_valid | end_valid | valid_intervals |
# +-------------------+----------------------+---------+-------------------------+-----------------+---------+-----------+-----------+---------------+------------------+--------------------+-------------+-----------+-----------------+
# | str               | str                  | str     | str                     | str             | str     |     int32 |     int32 |         int32 |            int32 |              int32 |        bool |      bool |            bool |
# +-------------------+----------------------+---------+-------------------------+-----------------+---------+-----------+-----------+---------------+------------------+--------------------+-------------+-----------+-----------------+
# | "ENSG00000168280" | "0"                  | "00_01" | "ptv_damaging_missense" | "breast_cancer" | "chr2"  | 148875227 | 149026759 |     242193529 |        149526759 |          148375227 |        True |      True |            True |
# | "ENSG00000179348" | "0"                  | "00_01" | "ptv_damaging_missense" | "breast_cancer" | "chr3"  | 128479427 | 128493201 |     198295559 |        128993201 |          127979427 |        True |      True |            True |
# | "ENSG00000054356" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr2"  | 219289623 | 219309648 |     242193529 |        219809648 |          218789623 |        True |      True |            True |
# | "ENSG00000103375" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr16" |  25215731 |  25228932 |      90338345 |         25728932 |           24715731 |        True |      True |            True |
# | "ENSG00000150477" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr18" |  36829106 |  37232172 |      80373285 |         37732172 |           36329106 |        True |      True |            True |
# | "ENSG00000164897" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr7"  | 151081085 | 151083493 |     159345973 |        151583493 |          150581085 |        True |      True |            True |
# | "ENSG00000174944" | "0.0829886563419236" | "00_01" | "synonymous"            | "breast_cancer" | "chr3"  | 151212117 | 151278542 |     198295559 |        151778542 |          150712117 |        True |      True |            True |
# | "ENSG00000176428" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr7"  |  73667831 |  73672112 |     159345973 |         74172112 |           73167831 |        True |      True |            True |
# | "ENSG00000182325" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr8"  | 144355431 | 144359376 |     145138636 |        144859376 |          143855431 |        True |      True |            True |
# | "ENSG00000187559" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr9"  |  68302867 |  68305084 |     138394717 |         68805084 |           67802867 |        True |      True |            True |
# | "ENSG00000204070" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr20" |  45361937 |  45376798 |      64444167 |         45876798 |           44861937 |        True |      True |            True |
# | "ENSG00000204388" | "0.0099241650987275" | "00_01" | "synonymous"            | "breast_cancer" | "chr6"  |  31827738 |  31830254 |     170805979 |         32330254 |           31327738 |        True |      True |            True |
# | "ENSG00000254806" | "0"                  | "00_01" | "synonymous"            | "breast_cancer" | "chr20" |  45363200 |  45410610 |      64444167 |         45910610 |           44863200 |        True |      True |            True |
# +-------------------+----------------------+---------+-------------------------+-----------------+---------+-----------+-----------+---------------+------------------+--------------------+-------------+-----------+-----------------+
#
# +---------------------------------+
# | intervals                       |
# +---------------------------------+
# | interval<locus<GRCh38>>         |
# +---------------------------------+
# | [chr2:148875227-chr2:149026759] |
# | [chr3:128479427-chr3:128493201] |
# | [chr2:219289623-chr2:219309648] |
# | [chr16:25215731-chr16:25228932] |
# | [chr18:36829106-chr18:37232172] |
# | [chr7:151081085-chr7:151083493] |
# | [chr3:151212117-chr3:151278542] |
# | [chr7:73667831-chr7:73672112]   |
# | [chr8:144355431-chr8:144359376] |
# | [chr9:68302867-chr9:68305084]   |
# | [chr20:45361937-chr20:45376798] |
# | [chr6:31827738-chr6:31830254]   |
# | [chr20:45363200-chr20:45410610] |
# +---------------------------------+

# %%
chromosomes = [x.replace('chr','') for x in list(set(ht.contig.collect()))]

# %%
mt = genotypes.get_ukb_genotypes_bed(chromosomes)
mt = mt.annotate_rows(**{'info': hl.agg.call_stats(mt.GT, mt.alleles)})
# Out:
# 2021-11-29 20:10:48 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:48 Hail: INFO: Found 38591 variants in bim file.
# 2021-11-29 20:10:50 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:50 Hail: INFO: Found 28960 variants in bim file.
# 2021-11-29 20:10:51 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:51 Hail: INFO: Found 52300 variants in bim file.
# 2021-11-29 20:10:53 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:53 Hail: INFO: Found 34310 variants in bim file.
# 2021-11-29 20:10:54 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:54 Hail: INFO: Found 19959 variants in bim file.
# 2021-11-29 20:10:56 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:56 Hail: INFO: Found 42722 variants in bim file.
# 2021-11-29 20:10:58 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:58 Hail: INFO: Found 53695 variants in bim file.
# 2021-11-29 20:10:59 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:10:59 Hail: INFO: Found 61966 variants in bim file.
# 2021-11-29 20:11:01 Hail: INFO: Found 488377 samples in fam file.
# 2021-11-29 20:11:01 Hail: INFO: Found 21962 variants in bim file.

# %%
# filter to common variants
mt = mt.annotate_rows(info = mt.info.annotate(AC = mt.info.AC[1]))
mt = mt.annotate_rows(info = mt.info.annotate(AF = mt.info.AF[1]))
mt = qc.filter_min_maf(mt, 0.01)

# %%
:q
# Out:
# [Interval(start=Locus(contig=chr2, position=148875227, reference_genome=GRCh38), end=Locus(contig=chr2, position=149026759, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr3, position=128479427, reference_genome=GRCh38), end=Locus(contig=chr3, position=128493201, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr2, position=219289623, reference_genome=GRCh38), end=Locus(contig=chr2, position=219309648, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr16, position=25215731, reference_genome=GRCh38), end=Locus(contig=chr16, position=25228932, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr18, position=36829106, reference_genome=GRCh38), end=Locus(contig=chr18, position=37232172, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr7, position=151081085, reference_genome=GRCh38), end=Locus(contig=chr7, position=151083493, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr3, position=151212117, reference_genome=GRCh38), end=Locus(contig=chr3, position=151278542, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr7, position=73667831, reference_genome=GRCh38), end=Locus(contig=chr7, position=73672112, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr8, position=144355431, reference_genome=GRCh38), end=Locus(contig=chr8, position=144359376, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr9, position=68302867, reference_genome=GRCh38), end=Locus(contig=chr9, position=68305084, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr20, position=45361937, reference_genome=GRCh38), end=Locus(contig=chr20, position=45376798, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr6, position=31827738, reference_genome=GRCh38), end=Locus(contig=chr6, position=31830254, reference_genome=GRCh38), includes_start=True, includes_end=True),
#  Interval(start=Locus(contig=chr20, position=45363200, reference_genome=GRCh38), end=Locus(contig=chr20, position=45410610, reference_genome=GRCh38), includes_start=True, includes_end=True)]

# %%
ht.intervals.describe()
# Out:
# --------------------------------------------------------
# Type:
#         interval<locus<GRCh38>>
# --------------------------------------------------------
# Source:
#     <hail.table.Table object at 0x2b44231b2ef0>
# Index:
#     ['row']
# --------------------------------------------------------

# %%
# perform liftover to GRCh38
mt = variants.liftover(mt)

# %%
# filter to variants in the the locus
#mt = hl.filter_intervals(mt, ht.intervals.collect())

# %%
# count variants in locus
n = mt.count()
print('filtered')

# %%
test = hl.import_locus_intervals('derived/tables/gene_intervals/test.txt', reference_genome='GRCh37')
# Out:
# 2021-11-29 20:27:28 Hail: INFO: Reading table without type imputation
#   Loading field 'f0' as type str (user-supplied)
#   Loading field 'f1' as type int32 (user-supplied)
#   Loading field 'f2' as type int32 (user-supplied)

# %%
test = test.annotate(blah = 1)
test.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'interval': interval<locus<GRCh37>>
#     'blah': int32
# ----------------------------------------
# Key: ['interval']
# ----------------------------------------

# %%
test[mt.locus].describe()
# Out:
# --------------------------------------------------------
# Type:
#         struct {
#         blah: int32
#     }
# --------------------------------------------------------
# Source:
#     <hail.matrixtable.MatrixTable object at 0x2b44234800f0>
# Index:
#     ['row']
# --------------------------------------------------------

# %%
test.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'interval': interval<locus<GRCh37>>
# ----------------------------------------
# Key: ['interval']
# ----------------------------------------

# %%
ht = ht.select('intervals').key_by('intervals')

# %%
ht[mt.locus]
# Out:
# <StructExpression of type struct{}>

# %% [markdown]
# # Merge markers

# %%
path = "derived/knockouts/211111/ukb_wes_200k_maf00_50_chr7_ptv_ptv_LC_ko.vcf.bgz"
mt = hl.import_vcf(path)

# %%
mt.count()
# Out:
# 2021-12-06 13:58:07 Hail: INFO: Coerced sorted dataset
# (0, 176929)

# %%
mt.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {}
# ----------------------------------------
# Entry fields:
#     'DS': float64
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------

# %%
mt.DS.show()
# Out:
# 2021-12-06 13:58:00 Hail: INFO: Coerced sorted dataset
# 2021-12-06 13:58:03 Hail: INFO: Coerced sorted dataset
# +---------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+
# | locus         | alleles    | '1705888'.DS | '3544034'.DS | '1065590'.DS | '1130642'.DS | '1237482'.DS | '2351928'.DS | '3310264'.DS | '5800421'.DS | '3708144'.DS | '1728817'.DS | '1663370'.DS | '1116994'.DS | '5254480'.DS | '2469141'.DS | '3099220'.DS |
# +---------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+
# | locus<GRCh38> | array<str> |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |      float64 |
# +---------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+
# +---------------+------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+--------------+
#
# +--------------+
# | '1944907'.DS |
# +--------------+
# |      float64 |
# +--------------+
# +--------------+
# showing the first 16 of 176929 columns

# %%
path = '/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/conditional/common/211111_spa_conditional_synonymous_breast_cancer_conditioning_markers.txt'
ht = hl.import_table(path, delimiter = ' ', no_header = True)
# Out:
# 2021-12-08 16:48:47 Hail: INFO: Loading 32 fields. Counts by type:
#   str: 32

# %%
ht.show()
# Out:
# +--------+------------+-------------+-----+-----+------------------+---------------------+-----+---------+----------------------+----------------------+
# | f0     | f1         | f2          | f3  | f4  | f5               | f6                  | f7  | f8      | f9                   | f10                  |
# +--------+------------+-------------+-----+-----+------------------+---------------------+-----+---------+----------------------+----------------------+
# | str    | str        | str         | str | str | str              | str                 | str | str     | str                  | str                  |
# +--------+------------+-------------+-----+-----+------------------+---------------------+-----+---------+----------------------+----------------------+
# | "chr6" | "31122301" | "rs6913137" | "G" | "T" | "111719.4765625" | "0.900701999664307" | "1" | "62018" | "-0.145365813010606" | "0.0333610866392428" |
# +--------+------------+-------------+-----+-----+------------------+---------------------+-----+---------+----------------------+----------------------+
#
# +---------------------+-----------------------+------------------------+-----+--------------------+--------------------+--------------------+
# | f11                 | f12                   | f13                    | f14 | f15                | f16                | f17                |
# +---------------------+-----------------------+------------------------+-----+--------------------+--------------------+--------------------+
# | str                 | str                   | str                    | str | str                | str                | str                |
# +---------------------+-----------------------+------------------------+-----+--------------------+--------------------+--------------------+
# | "-131.007605512452" | "1.3164878483871e-05" | "1.27736960839858e-05" | "1" | "901.227068450362" | "908.853185762126" | "0.88879367921549" |
# +---------------------+-----------------------+------------------------+-----+--------------------+--------------------+--------------------+
#
# +---------------------+--------+---------+--------+--------+---------+---------+-----+-----+-----+-----+-----+---------------------+-----------------------+
# | f18                 | f19    | f20     | f21    | f22    | f23     | f24     | f25 | f26 | f27 | f28 | f29 | f30                 | f31                   |
# +---------------------+--------+---------+--------+--------+---------+---------+-----+-----+-----+-----+-----+---------------------+-----------------------+
# | str                 | str    | str     | str    | str    | str     | str     | str | str | str | str | str | str                 | str                   |
# +---------------------+--------+---------+--------+--------+---------+---------+-----+-----+-----+-----+-----+---------------------+-----------------------+
# | "0.901909824781689" | "5711" | "56307" | "4521" | "1110" | "45754" | "10070" | ""  | ""  | ""  | ""  | ""  | "-131.007605512452" | "1.3164878483871e-05" |
# +---------------------+--------+---------+--------+--------+---------+---------+-----+-----+-----+-----+-----+---------------------+-----------------------+

# %%
ht = ht.annotate(variant = hl.delimit([ht.f0, ht.f1, ht.f3, ht.f4], ':'))
ht = ht.key_by(**hl.parse_variant(ht.variant))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-0335ef04f628> in <module>
# ----> 1 ht = ht.annotate(variant = hl.delimit([ht.f0, ht.f1, ht.f3, ht.f4], ':'))
#       2 ht = ht.key_by(**hl.parse_variant(ht.variant))
#
# NameError: name 'ht' is not defined

# %%
chromosomes = [x.replace('chr', '') for x in list(set(ht.locus.contig.collect()))]
mt = genotypes.get_ukb_imputed_v3_bgen(chromosomes)
mt = variants.liftover(mt)
mt = mt.filter_rows(hl.is_defined(ht[mt.row_key]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-3b2f54ee5245> in <module>
# ----> 1 chromosomes = [x.replace('chr', '') for x in list(set(ht.locus.contig.collect()))]
#       2 mt = genotypes.get_ukb_imputed_v3_bgen(chromosomes)
#       3 mt = variants.liftover(mt)
#       4 mt = mt.filter_rows(hl.is_defined(ht[mt.row_key]))
#
# NameError: name 'ht' is not defined

# %%
mt = hl.read_matrix_table( "derived/knockouts/211206/ukb_wes_200k_maf0_0.01_chr21_ptv_damaging_missense_ko.mt")
mt = mt.drop('eur')
imp = genotypes.get_ukb_imputed_v3_bgen([21])
# Out:
# 2021-12-08 21:39:46 Hail: INFO: Number of BGEN files parsed: 1
# 2021-12-08 21:39:46 Hail: INFO: Number of samples in BGEN files: 487409
# 2021-12-08 21:39:46 Hail: INFO: Number of variants across all BGEN files: 1261158

# %%
mt_sids = mt.s.collect()
imp_sids = imp.s.collect()
overlap = list(set(mt_sids) & set(imp_sids))[1:5]

# %%
mt = mt.filter_cols(hl.literal(set(overlap)).contains(mt.s))
imp = imp.filter_cols(hl.literal(set(overlap)).contains(imp.s))

# %%
imp = imp.head(1)
imp = variants.liftover(imp)
imp = imp.drop('varid','new_locus','new_alleles','old_locus')
imp = imp.annotate_entries(DS = imp.dosage)
imp = imp.select_entries(imp.DS)

# %%
mt = mt.key_cols_by('s')
imp = imp.key_cols_by('s')

# %%
#mt_sids = mt.s.collect()
#mt_s_index = [i[0] for i in sorted(enumerate(mt_sids), key=lambda x:x[1])]
#imp_sids = mt.s.collect()
#imp_s_index = [i[0] for i in sorted(enumerate(imp_sids), key=lambda x:x[1])]

# %%
mt = mt.add_col_index()

# %%
mt.index_cols(imp.s)
# Out:
# <StructExpression of type struct{}>

# %%
#mt = mt.annotate_cols(s_new = imp.cols()[mt.s])
#imp = imp.annotate_cols(s_new = imp.s)

# %%
#mt = mt.key_cols_by('s_new')
#imp = imp.key_cols_by('s_new')
#mt = mt.drop('s')
#imp = imp.drop('s')

# %%
print(mt.describe())
print('###')
print(imp.describe())
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
# ----------------------------------------
# Entry fields:
#     'DS': float64
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------
# None
# ###
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
# ----------------------------------------
# Entry fields:
#     'DS': float64
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------
# None

# %%
imp.union_rows(mt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-d2540e06a168> in <module>
# ----> 1 imp.union_rows(mt)
#
# <decorator-gen-1309> in union_rows(_check_cols, *datasets)
#
# /well/lindgren/users/mmq446/conda/skylake/envs/hail-updated/lib/python3.6/site-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     575     def wrapper(__original_func, *args, **kwargs):
#     576         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 577         return __original_func(*args_, **kwargs_)
#     578
#     579     return wrapper
#
# /well/lindgren/users/mmq446/conda/skylake/envs/hail-updated/lib/python3.6/site-packages/hail/matrixtable.py in union_rows(_check_cols, *datasets)
#    3606                     .find(lambda x: ~(x[1] == first_keys))[0])))
#    3607                 if wrong_keys is not None:
# -> 3608                     raise ValueError(f"'MatrixTable.union_rows' expects all datasets to have the same columns. "
#    3609                                      f"Datasets 0 and {wrong_keys + 1} have different columns (or possibly different order).")
#    3610             return MatrixTable(ir.MatrixUnionRows(*[d._mir for d in datasets]))
#
# ValueError: 'MatrixTable.union_rows' expects all datasets to have the same columns. Datasets 0 and 1 have different columns (or possibly different order).
