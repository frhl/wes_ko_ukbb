# %%
import os
import hail as hl

# %%
from ukb_utils import hail_init
from ukb_utils import genotypes

# %%
# startup hail
hail_init.hail_bmrc_init('../logs/hail_grm.log', 'GRCh37')
# Out:
# Running on Apache Spark version 3.1.2
# SparkUI available at http://compe041.hpc.in.bmrc.ox.ac.uk:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.74-0c3a74d12093
# LOGGING: writing to ../logs/hail_grm.log

# %%
# get markers used in UKBB kinship calculation
ht = hl.import_table('/well/lindgren/UKBIOBANK/DATA/QC/ukb_snp_qc.txt', impute = True, delimiter = ' ')
ht = ht.filter(ht.in_Relatedness == 1)
rsids = ht.rs_id.collect()
# Out:
# 2021-09-08 15:19:20 Hail: WARN: Found 3 duplicate columns. Mangled columns follows:
#   'PC9_loading' -> 'PC9_loading_1'
#   'PC9_loading' -> 'PC9_loading_2'
#   'PC9_loading' -> 'PC9_loading_3'
# 2021-09-08 15:19:20 Hail: INFO: Reading table to impute column types
# 2021-09-08 15:19:43 Hail: WARN: Found 3 duplicate columns. Mangled columns follows:
#   'PC9_loading' -> 'PC9_loading_1'
#   'PC9_loading' -> 'PC9_loading_2'
#   'PC9_loading' -> 'PC9_loading_3'
# 2021-09-08 15:19:43 Hail: INFO: Loading 159 fields. Counts by type:
#   int32: 113
#   float64: 40
#   str: 6

# %%
# combine multiple matrix tables
mt = genotypes.get_ukb_imputed_v3_bgen([22])
mt = mt.filter_rows(hl.literal(rsids).contains(mt.rsid))
# Out:
# 2021-09-08 15:25:51 Hail: INFO: Number of BGEN files parsed: 1
# 2021-09-08 15:25:51 Hail: INFO: Number of samples in BGEN files: 487409
# 2021-09-08 15:25:51 Hail: INFO: Number of variants across all BGEN files: 1255683

# %%
# Out:
# (1495, 487409)

# %%
import os
import hail as hl
from ukb_utils import hail_init
from ukb_utils import genotypes

def main(args):

    hail_init.hail_bmrc_init('../logs/hail_grm.log', 'GRCh37')
    
    # input variables
    chroms = args.chroms
    subset_markers_by_kinship = args.subset_markers_by_kinship
    out_prefix = args.out_prefix
    out_type = args.out_type
        
    # combine multiple matrix tables
    mt = genotypes.get_ukb_imputed_v3_bgen([22])
    
    # get markers used in UKBB kinship calculation
    ht = hl.import_table('/well/lindgren/UKBIOBANK/DATA/QC/ukb_snp_qc.txt', 
                         impute = True, delimiter = ' ')
    
    # createse a sparse GRM
    if subset_markers_by_kinship:
        ht = ht.filter(ht.in_Relatedness == 1)
        rsids = ht.rs_id.collect()
        mt = mt.filter_rows(hl.literal(rsids).contains(mt.rsid))
    
    hl.export_plink(ds, out_prefix, ind_id = mt.s)
    
if __name__=='__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--chroms', default=None, help='Path to input')
    parser.add_argument('--subset_markers_by_kinship', action='store_true', help='Only use markers that have been used in UKBB as kinship markers')
    parser.add_argument('--out_prefix', default=None, help='Path prefix for output dataset (plink format)')
    args = parser.parse_args()

    main(args)
