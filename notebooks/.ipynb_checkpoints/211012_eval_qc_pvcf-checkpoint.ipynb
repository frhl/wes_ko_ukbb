# %%
import hail as hl
#import argparse
#import pandas
import os

from ukb_utils import hail_init
from ukb_utils import genotypes
from ko_utils import qc
from ko_utils import analysis
from gnomad.utils.vep import process_consequences

# %%
os.chdir('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/')
hail_init.hail_bmrc_init('logs/hail/hail_eval_qc.log', 'GRCh38')
# Out:
# Running on Apache Spark version 3.1.2
# SparkUI available at http://compe034.hpc.in.bmrc.ox.ac.uk:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.77-684f32d73643
# LOGGING: writing to logs/hail/hail_test_export.log

# %%
in_wes="/well/ukbb-wes/pvcf/oqfe/ukbb-wes-oqfe-pvcf-chr21.vcf.gz"

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-07f256301a43> in <module>
#       1 #mt = qc.get_table(in_wes, 'vcf')
# ----> 2 mt.entries().show()
#
# <decorator-gen-1141> in show(self, n, width, truncate, types, handler, n_rows)
#
# /well/lindgren/users/mmq446/conda/skylake/envs/hail-updated/lib/python3.6/site-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     575     def wrapper(__original_func, *args, **kwargs):
#     576         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 577         return __original_func(*args_, **kwargs_)
#     578
#     579     return wrapper
#
# /well/lindgren/users/mmq446/conda/skylake/envs/hail-updated/lib/python3.6/site-packages/hail/table.py in show(***failed resolving arguments***)
#    1505         if handler is None:
# ...

# %%
# Assume mt1 has no vep annotations
#mt1 = process_consequences(hl.vep(mt1, 'utils/vep_env.json')) 
mt1 = qc.recalc_info(mt1)
    mt2 = qc.recalc_info(mt2)
    
    # remove invariant sites before calculating AF
    n = 1
    mt1 = mt1.filter_rows(mt1.info.AC>=n)
    mt2 = mt2.filter_rows(mt2.info.AC>=n)
    
    # Re-annotate af
    mt1 = qc.recalc_info(mt1)
    mt2 = qc.recalc_info(mt2)

    # only one consequence per variant
    mt1 = mt1.explode_rows(mt1.vep.worst_csq_by_gene_canonical)
    mt2 = mt2.explode_rows(mt2.vep.worst_csq_by_gene_canonical)

    # aggregate variants by individual and do a count for WES data
    burden_mt1 = mt1.annotate_cols(csqs=hl.agg.counter(mt1.vep.worst_csq_by_gene_canonical.most_severe_consequence, weight=mt1.GT.n_alt_alleles()))

    # aggregate variants by individual and do a for IMP data
    burden_mt2 = mt2.annotate_cols(csqs=hl.agg.counter(mt2.vep.worst_csq_by_gene_canonical.most_severe_consequence, weight=mt2.GT.n_alt_alleles()))
    
    # save data so we can open it up in a notebook
    if checkpoint:
        burden_mt1.write(out_prefix + "_wes_checkpoint.mt")
        burden_mt2.write(out_prefix + "_imp_checkpoint.mt")

    # write stats for wes data
    mt1_out = burden_mt1.filter_rows((burden_mt1.info.AF >= min_af) & 
                                        (burden_mt1.info.AF < max_af))
    mt1_out_prefix = out_prefix + '_wes_vep_af' + str(int(min_af*100)) + '.tsv'
    mt1_out.csqs.export(mt1_out_prefix)
    
    # write stats for imputed data
    mt2_out = burden_mt2.filter_rows((burden_mt2.info.AF >= min_af) & 
                                        (burden_mt2.info.AF < max_af) & 
                                        (burden_mt2.info_score >= min_info))
    mt2_out_prefix = out_prefix + '_ukb_imp_vep_af' + str(int(min_af*100)) + '_info' + str(int(min_info*100)) + '.tsv'
    mt2_out.csqs.export(mt2_out_prefix)
    
    # save one category
    mt1 = mt1.filter_rows(mt1.vep.worst_csq_by_gene_canonical.most_severe_consequence == 'stop_lost')
    mt2 = mt2.filter_rows(mt2.vep.worst_csq_by_gene_canonical.most_severe_consequence == 'stop_lost')

    # filter entries by presence of alternate allele
    mt1 = mt1.filter_entries(mt1.GT.is_non_ref())
    mt2 = mt1.filter_entries(mt2.GT.is_non_ref())

    # save to file so we can look through it
    mt1.drop('vep').drop('vep_proc_id').entries().export(out_prefix + 'wes_entries_stop_lost.tsv.bgz')
    mt2.drop('vep').drop('vep_proc_id').entries().export(out_prefix + 'imp_entries_stop_lost.tsv.bgz')
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         AF: float64,
#         AQ: array<int32>,
#         AC: int32,
#         AN: int32
#     }
# ----------------------------------------
# Entry fields:
#     'GT': call
#     'RNC': array<str>
#     'DP': int32
#     'AD': array<int32>
#     'GQ': int32
#     'PL': array<int32>
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------
