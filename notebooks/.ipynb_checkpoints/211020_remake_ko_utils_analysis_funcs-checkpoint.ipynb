# %%
import hail as hl
import os

from ukb_utils import hail_init
from ukb_utils import genotypes
from ko_utils import qc
from ko_utils import analysis

# %%
os.chdir('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/')
hail_init.hail_bmrc_init('logs/hail/hail_test_export.log', 'GRCh38')
# Out:
# 2021-10-20 22:39:42 Hail: WARN: Hail has already been initialized. If this call was intended to change configuration, close the session with hl.stop() first.
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# <ipython-input-3-863586f1e1b6> in <module>
#       1 os.chdir('/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/')
# ----> 2 hail_init.hail_bmrc_init('logs/hail/hail_test_export.log', 'GRCh38')
#
# /well/lindgren/flassen/ressources/ukb/ukb_utils/python/ukb_utils/hail_init.py in hail_bmrc_init(log, default_reference)
#      10         default_reference=default_reference,
#      11         append=True,
# ---> 12         master='local[%s]' % os.environ.get('NSLOTS', 1) # Required to prevent using more CPU resources than requested
#      13     )
#      14
#
# ...

# %%
path1 = '/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/qc/ukb_wes_200k_chr1_variants_unphased.ht'
path2 = '/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/data/qc/ukb_wes_200k_chr1_variants_phased.ht'
mt1 = hl.read_table(path1)
mt2 = hl.read_table(path2)

# %%
# load VEP annotation table
input_annotation_path = "data/vep/hail/ukb_wes_200k_chr1_vep.ht"
consequence_annotations = hl.read_table(input_annotation_path)
mt1 = mt1.annotate(consequence = consequence_annotations[mt1.key]) 
mt2 = mt2.annotate(consequence = consequence_annotations[mt2.key])
