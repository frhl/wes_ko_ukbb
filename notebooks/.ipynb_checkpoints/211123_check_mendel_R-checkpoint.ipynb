# %%
library(data.table)

# %%
setwd('/gpfs3/well/lindgren/UKBIOBANK/flassen/projects/KO/wes_ko_ukbb/')

# %%
d <- fread('data/mendel//ukb_wes_200k_chr21_mendel_cat.tsv.gz')

# %%
d[d$mendel.errors > 0]
# Out:
#   locus          alleles                        count.coding_snp
# 1 chr21:33555090 ["AAGCCGCCGCAGCCGCACCCCC","A"]     0
# 2 chr21:42111162 ["GCCCCAGCCAGGTGAA","G"]           0
# 3 chr21:46155458 ["C","T"]                      83999
# 4 chr21:46497134 ["CT","C"]                         0
# 5 chr21:46547002 ["G","A"]                          5
#   count.coding_indel mendel.errors csq_category
# 1   9441             7             other_missense
# 2     28             1             other_missense
# 3      0             1             non_coding
# 4 167387             1             non_coding
# 5      0             1             other_missense

# %%
print(dim(d[d$count.coding_snp == 1]))
print(dim(d[d$count.coding_indel == 1]))
# Out:
# [1] 39043     6
# [1] 2351    6
