# %%
setwd("/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb")
library(data.table)

# %%
d <- fread("data/conditional/rare/combined/ukb_eur_wes_200k_chr21_maf0to5e-2_pLoF_damaging_missense_LD_bin.txt.gz")

# %%
head(d)
# Out:
#   chr   pos id              ref  alt  BC_combined
# 1 chr21  1  ENSG00000141956 UpSX zBVE b1715791386b92d5adfc7dc8c31f67b4
# 2 chr21  2  ENSG00000141959 mGzq EoIP 6f697abeb9d7660f1aac545ec2d48c1f
# 3 chr21  4  ENSG00000142156 UpCp rWjl 6b7e16e983ebd1adfc0bf66399b9a8ea
# 4 chr21  7  ENSG00000142173 fMTb okHJ a661f9223308b023a4652f30fc3bcc18
# 5 chr21  9  ENSG00000142185 nibn ppVn ac6e06a18dfeca685a50b23abd6f7169
# 6 chr21 11  ENSG00000142192 uFwA aBgc 08b87eccf61ef62ab1aef0ff25a80671
#   BC_combined_primary_care         CAD_combined
# 1 b1715791386b92d5adfc7dc8c31f67b4 9bcbd47cd7b76442fc0988fa694c960a
# 2 6f697abeb9d7660f1aac545ec2d48c1f 823b09474607f4a85b4efade051120f0
# 3 6b7e16e983ebd1adfc0bf66399b9a8ea 4126133f7ce3f12fb8e0951c6719261a
# 4 a661f9223308b023a4652f30fc3bcc18 6479fc30d073db29c4f5372a1e54e849
# 5 ac6e06a18dfeca685a50b23abd6f7169 137a955ae04be94595acbaf8a2dc9a3c
# 6 08b87eccf61ef62ab1aef0ff25a80671 42f017f3b4944a83a668244f6f4204fd
# ...

# %%
lapply(d, function(x) sum(duplicated(d)))
# Out:
# $chr
# [1] 93
#
# $pos
# [1] 93
#
# $id
# [1] 93
#
# $ref
# [1] 93
#
# $alt
# [1] 93
#
# $BC_combined
# [1] 93
#
# $BC_combined_primary_care
# [1] 93
#
# $CAD_combined
# [1] 93
#
# $CAD_combined_primary_care
# [1] 93
#
# $COPD_combined
# [1] 93
#
# $COPD_combined_primary_care
# [1] 93
#
# $CLD_combined
# [1] 93
#
# $CLD_combined_primary_care
# [1] 93
#
# $CC_combined
# [1] 93
#
# $CC_combined_primary_care
# [1] 93
#
# $DEM_combined
# [1] 93
#
# $DEM_combined_primary_care
# [1] 93
#
# $INF_combined
# [1] 93
#
# $INF_combined_primary_care
# [1] 93
#
# $LC_combined
# [1] 93
#
# $LC_combined_primary_care
# [1] 93
#
# $NAFLD_combined
# [1] 93
#
# $NAFLD_combined_primary_care
# [1] 93
#
# $RF_combined
# [1] 93
#
# $RF_combined_primary_care
# [1] 93
#
# $RF_acute_combined
# [1] 93
#
# $RF_acute_combined_primary_care
# [1] 93
#
# $RF_chronic_combined
# [1] 93
#
# $RF_chronic_combined_primary_care
# [1] 93
#
# $STR_combined
# [1] 93
#
# $STR_combined_primary_care
# [1] 93
#
# ...

# %%
d()
