# %%
setwd('/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb')
library(data.table)
library(ggplot2)
library(ggrepel)
library(stringr)
devtools::load_all('utils/modules/R/gwastools')
# Out:
# i Loading gwastools
#
# Warning message in setup_ns_exports(path, export_all, export_imports):
# "Objects listed as exports, but not present in namespace: summarize_bcftools_trio_stats"

# %% [markdown]
# # Simulating absence of effect

# %%
files <- list.files('data/simulation/saige/step2', pattern = ".txt$", full.names = TRUE)

# %%
files <- files[grepl("eur_h2_0.0_0.0_pi_0.0_0.0_K_0.1", files)]
head(files)
#files <- "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_8_pLoF_damaging_missense.txt"
# Out:
# [1] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.0_pi_0.0_0.0_K_0.1_chr21_y_cts_10_pLoF_damaging_missense.txt"
# [2] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.0_pi_0.0_0.0_K_0.1_chr21_y_cts_11_pLoF_damaging_missense.txt"
# [3] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.0_pi_0.0_0.0_K_0.1_chr21_y_cts_12_pLoF_damaging_missense.txt"
# [4] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.0_pi_0.0_0.0_K_0.1_chr21_y_cts_13_pLoF_damaging_missense.txt"
# [5] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.0_pi_0.0_0.0_K_0.1_chr21_y_cts_14_pLoF_damaging_missense.txt"
# [6] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.0_pi_0.0_0.0_K_0.1_chr21_y_cts_15_pLoF_damaging_missense.txt"

# %%
#phenos <- list.files('data/simulation/phenotypes/', pattern = ".tsv.gz$", full.names = TRUE)
#g <- fread('data/simulation/phenotypes/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_8_genes.tsv.gz')
#g <- g[g$theta > 0 & g$pKO > 0]
#print(nrow(g))
#head(g)
#gtabl <- as.data.frame(table(g$gene_id))
#colnames(gtabl) <- c('ensembl_gene_id', 'knockouts')

# %%
ribbon_p <- 0.95
d <- do.call(rbind, lapply(files, function(f){
    d <- fread(f)
    d$p.value.expt <- get_expected_p(d$p.value, na.rm = TRUE)
    n <- length(d$p.value)
    dt <- data.table(
        ensembl_gene_id = d$MarkerID[order(d$p.value)],
        pvalue.observed = -log10(sort(d$p.value)),
        pvalue.expected = -log10(sort(d$p.value.expt)),
        clower = -log10(qbeta(p = (1 - ribbon_p) / 2, shape2 = n:1, shape1 = 1:n)),
        cupper = -log10(qbeta(p = (1 + ribbon_p) / 2, shape2 = n:1, shape1 = 1:n)),
        iteration = gsub('cts_','',str_extract(f, "cts_[0-9]+")),
        parameters = str_extract(f, "h2_.+chr21")
        
    )
    return(dt)
}))

# %%
bonf <- 0.05 / (length(unique(d$ensembl_gene_id)) * length(unique(d$iteration)))
ggplot(d, aes(x=pvalue.expected, y=pvalue.observed, ymax=cupper, ymin=clower, color = iteration)) +
    geom_ribbon(fill="grey80", color="black", alpha = 0.7, linetype = 'dashed') +
    geom_line() +
    geom_point() +
    #geom_text_repel() + 
    geom_abline(linetype = 'dotted') + 
    scale_x_continuous(breaks=scales::pretty_breaks(n=10)) +
    scale_y_continuous(breaks=scales::pretty_breaks(n=10)) +
    xlab(expression(paste(-log[10],'(Expected P-value)' ))) +
    ylab(expression(paste(-log[10],'(Observed P-value)' ))) +
    geom_hline(yintercept = -log10(bonf), linetype = 'dashed', color = 'red') +
    ggtitle("Simulated phenotypes (h2=0)", "pLoF + Damaging_missense") +
    theme(axis.title.x = element_text(margin=ggplot2::margin(t=10)),
          axis.title.y = element_text(margin=ggplot2::margin(r=10)),
          plot.title = element_text(hjust=0.5),
          plot.subtitle = element_text(hjust=0.5))
# Out:
# plot without title

# %% [markdown]
# ## Simulate effect present

# %%
regex <- "ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1"
files <- list.files('data/simulation/saige/step2', pattern = ".txt$", full.names = TRUE)
files <- files[grepl(regex, files)]
files
# Out:
#  [1] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_10_pLoF_damaging_missense.txt"
#  [2] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_11_pLoF_damaging_missense.txt"
#  [3] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_12_pLoF_damaging_missense.txt"
#  [4] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_13_pLoF_damaging_missense.txt"
#  [5] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_14_pLoF_damaging_missense.txt"
#  [6] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_15_pLoF_damaging_missense.txt"
#  [7] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_1_pLoF_damaging_missense.txt"
#  [8] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_2_pLoF_damaging_missense.txt"
#  [9] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_3_pLoF_damaging_missense.txt"
# [10] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_4_pLoF_damaging_missense.txt"
# [11] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_5_pLoF_damaging_missense.txt"
# [12] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_6_pLoF_damaging_missense.txt"
# [13] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_7_pLoF_damaging_missense.txt"
# [14] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_8_pLoF_damaging_missense.txt"
# [15] "data/simulation/saige/step2/ukb_eur_h2_0.0_0.1_pi_0.0_0.1_K_0.1_chr21_y_cts_9_pLoF_damaging_missense.txt"

# %%
genes <- list.files('data/simulation/phenotypes/', pattern = "genes.tsv.gz$", full.names = TRUE)
genes <- genes[grepl(regex, genes)]
stopifnot(length(genes) > 0)
k <- do.call(rbind, lapply(genes, function(f){
    g <- fread(f)
    g <- g[g$theta > 0 & g$pKO > 0]
    gtabl <- as.data.frame(table(g$gene_id))
    if (nrow(gtabl) > 0 ){
        colnames(gtabl) <- c('ensembl_gene_id', 'knockouts')
        iteration <- gsub('_genes','',str_extract(f, "[0-9]+_genes"))
        gtabl$iteration <- iteration
        return(gtabl)
    } 
}))

# %%
ribbon_p <- 0.95
d <- do.call(rbind, lapply(files, function(f){
    d <- fread(f)
    d$p.value.expt <- get_expected_p(d$p.value, na.rm = TRUE)
    n <- length(d$p.value)
    dt <- data.table(
        ensembl_gene_id = d$MarkerID[order(d$p.value)],
        pvalue.observed = -log10(sort(d$p.value)),
        pvalue.expected = -log10(sort(d$p.value.expt)),
        clower = -log10(qbeta(p = (1 - ribbon_p) / 2, shape2 = n:1, shape1 = 1:n)),
        cupper = -log10(qbeta(p = (1 + ribbon_p) / 2, shape2 = n:1, shape1 = 1:n)),
        iteration = gsub('cts_','',str_extract(f, "cts_[0-9]+")),
        parameters = str_extract(f, "h2_.+chr21")
        
    )
    return(dt)
}))

# %%
final <- merge(d, k, by = c("ensembl_gene_id", "iteration"), all.x = TRUE)

# %%
options(repr.plot.width=12, repr.plot.height=12)
bonf <- 0.05 / (length(unique(d$ensembl_gene_id)) * length(unique(d$iteration)))
ggplot(final, aes(x=pvalue.expected, y=pvalue.observed, ymax=cupper, ymin=clower, color = iteration, label = knockouts)) +
    geom_ribbon(fill="grey80", color="black", alpha = 0.7, linetype = 'dashed') +
    geom_line() +
    geom_point() +
    geom_text_repel(
        color = 'black', 
        min.segment.length = 0.2, 
        box.padding = 0.5,
        
    ) + 
    geom_abline(linetype = 'dotted') + 
    scale_x_continuous(breaks=scales::pretty_breaks(n=10)) +
    scale_y_continuous(breaks=scales::pretty_breaks(n=10)) +
    xlab(expression(paste(-log[10],'(Expected P-value)' ))) +
    ylab(expression(paste(-log[10],'(Observed P-value)' ))) +
    geom_hline(yintercept = -log10(bonf), linetype = 'dashed', color = 'red') +
    facet_wrap(~iteration, scales = "free") + 
    ggtitle("Simulated phenotypes (h2 = 0.1)", "pLoF + Damaging_missense") +
    theme(axis.title.x = element_text(margin=ggplot2::margin(t=10)),
          axis.title.y = element_text(margin=ggplot2::margin(r=10)),
          plot.title = element_text(hjust=0.5),
          plot.subtitle = element_text(hjust=0.5))
# Out:
# Warning message:
# "Removed 386 rows containing missing values (geom_text_repel)."
# plot without title

# %%
length(unique(d$ensembl_gene_id))
# Out:
# [1] 27
