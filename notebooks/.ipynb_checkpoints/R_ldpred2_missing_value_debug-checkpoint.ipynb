# %%
setwd("/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb")
devtools::load_all('utils/modules/R/prstools')
library(argparse)
# Out:
# i Loading PRStools
#
# Loading required package: bigsnpr
#
# Loading required package: bigstatsr
#
# Loading required package: data.table
#
# Loading required package: bigassertr

# %%
args <- list(
    chrom = "chr21",
    pred = "data/prs/hapmap/ukb_500k/ukb_hapmap_500k_eur_chr21.bed",
    ldsc = "data/prs/ldsc/ldsc_BMI.rds",
    ld_dir = "data/prs/hapmap/ld/matrix",
    method = 'auto',
    out_prefix = "data/prs/scores/auto/prs_auto_BMI_chr21",
    tmp_bfile = "data/prs/scores/auto/prs_auto_BMI_chr21.bfile"
)

# %%
# check args$chr
stopifnot(!is.null(args$chr))
stopifnot(file.exists(args$pred))
stopifnot(file.exists(args$ldsc))
stopifnot(!file.exists(args$tmp_bfile))
stopifnot(dir.exists(args$ld_dir))
stopifnot(dir.exists(dirname(args$out_prefix)))
stopifnot(args$method %in% c('inf', 'auto'))

# setup parallel environment
NCORES <- max(1, nb_cores())
bigparallelr::assert_cores(NCORES)
msg <- paste0("Running ldpred2 with ",NCORES," cores [",Sys.time(),"]")
write(msg,stdout())

# laod ldsc and qced GWAS
ldsc <- readRDS(args$ldsc)
gwas <- ldsc$gwas
h2 <- ldsc$h2_est

# Estimate h2 chromosome-wide
N_total <- nrow(gwas)
N_chr <- sum(gwas$chr == args$chr)
h2_init <- h2 * (N_chr / N_total)

# check estimates
stopifnot(h2_init > 0)
stopifnot(!is.null(gwas))
# Out:
# Running ldpred2 with 1 cores [2022-04-22 15:17:37]

# %%
h2_init
# Out:
# [1] 0.003577048

# %%
# get SNP correlations and LD
snp <- get_single_ld_matrix(gwas, chr = args$chrom, ld_dir = args$ld_dir)

# match GWAS with snp-correlation map
gwas <- gwas[na.omit(match(snp$map$marker, gwas$marker)), ]

# %%
# check that LD-matrix markers and gwas markers have overlap
# Check that ordering of markers are actually matching
stopifnot(all(gwas$marker %in% snp$map$marker))
stopifnot(all(snp$map$marker %in% gwas$marker))
stopifnot(sum(gwas$marker == snp$map$marker) / nrow(gwas) == 1)

# load data to be used for prediction
bfile <- tempfile(tmpdir = dirname(args$out_prefix))
pred <- load_bigsnp_from_bed(args$pred)
pred <- match_bigsnp_with_gwas(obj=pred, gwas=gwas, bfile=args$tmp_bfile)
genotypes <- pred$genotypes
indicies <- pred$gwas_indicies

stopifnot(!is.null(genotypes))
stopifnot(!is.null(indicies))

# %%
write("Running multi_auto", stderr())
#multi_auto <- snp_ldpred2_auto(
#    corr = snp$corr,
#    df_beta = gwas,
#    h2_init = h2_init,
#    vec_p_init = seq_log(1e-4, 0.9, 30),
#    ncores = NCORES)

# save data chains
multi_auto_path <- paste0(args$out_prefix,'_chains.rda')
multi_auto <- readRDS(multi_auto_path)

# %%
str(multi_auto)
# Out:
# List of 30
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002577 0.000569 0.000563 0.000563 0.000579 ...
#   ..$ postp_est  : num [1:16307] 0.203 0.198 0.198 0.198 0.198 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.188
#   ..$ h2_est     : num 0.00282
#   ..$ path_p_est : num [1:1500] 0.000201 0.000365 0.000484 0.000791 0.000717 ...
#   ..$ path_h2_est: num [1:1500] 0.000384 0.000657 0.000228 0.000695 0.000847 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 1e-04
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002691 0.000583 0.000592 0.000583 0.000598 ...
#   ..$ postp_est  : num [1:16307] 0.202 0.197 0.197 0.197 0.197 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.187
#   ..$ h2_est     : num 0.00295
#   ..$ path_p_est : num [1:1500] 0.000403 0.00095 0.00142 0.002232 0.001921 ...
#   ..$ path_h2_est: num [1:1500] 0.000179 0.000399 0.000718 0.000867 0.001216 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.000134
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002771 0.000597 0.000606 0.000591 0.000612 ...
#   ..$ postp_est  : num [1:16307] 0.296 0.29 0.29 0.289 0.29 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.281
#   ..$ h2_est     : num 0.00299
#   ..$ path_p_est : num [1:1500] 1.00e-05 1.46e-05 1.28e-05 5.08e-05 4.20e-04 ...
#   ..$ path_h2_est: num [1:1500] 0.0001 0.000162 0.0001 0.000124 0.000391 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00018
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002639 0.000584 0.000582 0.000577 0.000592 ...
#   ..$ postp_est  : num [1:16307] 0.203 0.198 0.198 0.197 0.198 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.188
#   ..$ h2_est     : num 0.00288
#   ..$ path_p_est : num [1:1500] 0.000208 0.000183 0.000823 0.001277 0.002042 ...
#   ..$ path_h2_est: num [1:1500] 0.000334 0.000256 0.000544 0.001099 0.000898 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.000241
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002708 0.000593 0.000595 0.000598 0.000612 ...
#   ..$ postp_est  : num [1:16307] 0.342 0.337 0.337 0.337 0.338 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.329
#   ..$ h2_est     : num 0.00291
#   ..$ path_p_est : num [1:1500] 0.000123 0.000107 0.000128 0.000165 0.000432 ...
#   ..$ path_h2_est: num [1:1500] 0.000187 0.0001 0.000128 0.000336 0.000347 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.000324
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002501 0.000532 0.000543 0.000535 0.000554 ...
#   ..$ postp_est  : num [1:16307] 0.106 0.1 0.1 0.1 0.101 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.091
#   ..$ h2_est     : num 0.00287
#   ..$ path_p_est : num [1:1500] 0.000365 0.001223 0.001526 0.002753 0.00197 ...
#   ..$ path_h2_est: num [1:1500] 0.000425 0.000745 0.000945 0.001309 0.001521 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.000434
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002727 0.000597 0.000605 0.000601 0.000612 ...
#   ..$ postp_est  : num [1:16307] 0.375 0.37 0.371 0.371 0.371 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.363
#   ..$ h2_est     : num 0.00292
#   ..$ path_p_est : num [1:1500] 0.000606 0.001244 0.001599 0.002139 0.002709 ...
#   ..$ path_h2_est: num [1:1500] 0.000594 0.000927 0.00102 0.001101 0.001478 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.000583
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002722 0.000601 0.000605 0.000599 0.000609 ...
#   ..$ postp_est  : num [1:16307] 0.323 0.318 0.318 0.318 0.318 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.309
#   ..$ h2_est     : num 0.00292
#   ..$ path_p_est : num [1:1500] 0.000923 0.001469 0.002396 0.003534 0.003925 ...
#   ..$ path_h2_est: num [1:1500] 0.000973 0.000748 0.001241 0.001464 0.001472 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.000781
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002623 0.000575 0.000578 0.000584 0.000591 ...
#   ..$ postp_est  : num [1:16307] 0.193 0.188 0.188 0.188 0.188 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.178
#   ..$ h2_est     : num 0.00287
#   ..$ path_p_est : num [1:1500] 0.001271 0.000948 0.00125 0.0017 0.001792 ...
#   ..$ path_h2_est: num [1:1500] 0.001168 0.001224 0.000664 0.000888 0.00119 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00105
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002562 0.000578 0.00058 0.000577 0.00059 ...
#   ..$ postp_est  : num [1:16307] 0.355 0.351 0.351 0.351 0.352 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.343
#   ..$ h2_est     : num 0.00275
#   ..$ path_p_est : num [1:1500] 0.0011 0.00161 0.00176 0.00249 0.00389 ...
#   ..$ path_h2_est: num [1:1500] 0.001045 0.001578 0.00089 0.001247 0.000968 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00141
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002509 0.000553 0.000553 0.000548 0.000569 ...
#   ..$ postp_est  : num [1:16307] 0.156 0.151 0.151 0.15 0.151 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.141
#   ..$ h2_est     : num 0.00277
#   ..$ path_p_est : num [1:1500] 0.00305 0.00481 0.00577 0.00545 0.0045 ...
#   ..$ path_h2_est: num [1:1500] 0.0015 0.00178 0.00214 0.00158 0.00188 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00189
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002698 0.000579 0.00058 0.000581 0.000593 ...
#   ..$ postp_est  : num [1:16307] 0.234 0.228 0.228 0.228 0.229 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.219
#   ..$ h2_est     : num 0.00292
#   ..$ path_p_est : num [1:1500] 0.00329 0.00328 0.00509 0.00488 0.00573 ...
#   ..$ path_h2_est: num [1:1500] 0.002 0.00171 0.00204 0.00188 0.00193 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00253
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002541 0.000548 0.00055 0.00055 0.000562 ...
#   ..$ postp_est  : num [1:16307] 0.2 0.194 0.194 0.194 0.195 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.186
#   ..$ h2_est     : num 0.00277
#   ..$ path_p_est : num [1:1500] 0.00375 0.00416 0.00417 0.00574 0.00563 ...
#   ..$ path_h2_est: num [1:1500] 0.00241 0.00201 0.00191 0.00198 0.00197 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00339
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002557 0.000552 0.000548 0.000548 0.000561 ...
#   ..$ postp_est  : num [1:16307] 0.135 0.129 0.129 0.129 0.129 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.119
#   ..$ h2_est     : num 0.00284
#   ..$ path_p_est : num [1:1500] 0.00446 0.0043 0.00592 0.00558 0.00626 ...
#   ..$ path_h2_est: num [1:1500] 0.00256 0.00179 0.00198 0.00144 0.00173 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00455
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002456 0.000522 0.000539 0.000525 0.000543 ...
#   ..$ postp_est  : num [1:16307] 0.0942 0.0886 0.0893 0.0886 0.0894 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.0793
#   ..$ h2_est     : num 0.00285
#   ..$ path_p_est : num [1:1500] 0.00548 0.00597 0.00717 0.00687 0.0075 ...
#   ..$ path_h2_est: num [1:1500] 0.00227 0.00215 0.00251 0.00232 0.00233 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00611
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002603 0.000571 0.000581 0.00058 0.00059 ...
#   ..$ postp_est  : num [1:16307] 0.214 0.208 0.209 0.209 0.209 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.199
#   ..$ h2_est     : num 0.00284
#   ..$ path_p_est : num [1:1500] 0.00923 0.00886 0.00965 0.0098 0.00887 ...
#   ..$ path_h2_est: num [1:1500] 0.00275 0.00286 0.00219 0.00224 0.00179 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.00819
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002617 0.000587 0.000591 0.000584 0.000597 ...
#   ..$ postp_est  : num [1:16307] 0.215 0.21 0.211 0.21 0.211 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.2
#   ..$ h2_est     : num 0.00285
#   ..$ path_p_est : num [1:1500] 0.0112 0.0106 0.0112 0.0107 0.0112 ...
#   ..$ path_h2_est: num [1:1500] 0.00314 0.00259 0.00243 0.00241 0.00225 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.011
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002507 0.000517 0.000518 0.000528 0.000533 ...
#   ..$ postp_est  : num [1:16307] 0.0991 0.0926 0.0927 0.0932 0.0934 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.0838
#   ..$ h2_est     : num 0.00288
#   ..$ path_p_est : num [1:1500] 0.0143 0.0156 0.0174 0.0162 0.014 ...
#   ..$ path_h2_est: num [1:1500] 0.00362 0.00313 0.0029 0.00296 0.00292 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.0147
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002461 0.000537 0.00055 0.00055 0.00056 ...
#   ..$ postp_est  : num [1:16307] 0.14 0.135 0.136 0.136 0.136 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.125
#   ..$ h2_est     : num 0.00274
#   ..$ path_p_est : num [1:1500] 0.0181 0.0199 0.0202 0.0191 0.0185 ...
#   ..$ path_h2_est: num [1:1500] 0.00322 0.00335 0.00297 0.00268 0.00284 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.0198
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002739 0.000609 0.000614 0.000609 0.000623 ...
#   ..$ postp_est  : num [1:16307] 0.462 0.458 0.458 0.458 0.458 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.451
#   ..$ h2_est     : num 0.00293
#   ..$ path_p_est : num [1:1500] 0.0248 0.0265 0.022 0.0217 0.0207 ...
#   ..$ path_h2_est: num [1:1500] 0.00345 0.00384 0.00335 0.00293 0.00257 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.0265
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002624 0.000567 0.000575 0.000571 0.000586 ...
#   ..$ postp_est  : num [1:16307] 0.223 0.217 0.217 0.217 0.218 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.208
#   ..$ h2_est     : num 0.00286
#   ..$ path_p_est : num [1:1500] 0.035 0.0375 0.0369 0.0367 0.0369 ...
#   ..$ path_h2_est: num [1:1500] 0.00382 0.00379 0.00369 0.00351 0.00331 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.0356
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002357 0.000494 0.000494 0.000486 0.000504 ...
#   ..$ postp_est  : num [1:16307] 0.0753 0.0697 0.0697 0.0693 0.0701 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.0616
#   ..$ h2_est     : num 0.00285
#   ..$ path_p_est : num [1:1500] 0.0539 0.056 0.0541 0.0491 0.0466 ...
#   ..$ path_h2_est: num [1:1500] 0.00381 0.00347 0.00298 0.00281 0.00299 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.0477
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002561 0.000594 0.000591 0.000593 0.000601 ...
#   ..$ postp_est  : num [1:16307] 0.332 0.328 0.328 0.328 0.328 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.318
#   ..$ h2_est     : num 0.00276
#   ..$ path_p_est : num [1:1500] 0.0667 0.0615 0.0629 0.0599 0.0621 ...
#   ..$ path_h2_est: num [1:1500] 0.00381 0.00343 0.00342 0.00339 0.00359 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.064
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002601 0.000563 0.000569 0.000569 0.00058 ...
#   ..$ postp_est  : num [1:16307] 0.196 0.19 0.191 0.191 0.191 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.181
#   ..$ h2_est     : num 0.00285
#   ..$ path_p_est : num [1:1500] 0.0823 0.0792 0.0794 0.0725 0.0722 ...
#   ..$ path_h2_est: num [1:1500] 0.00377 0.00359 0.00347 0.00341 0.00333 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.0858
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.00258 0.000581 0.000591 0.000582 0.000599 ...
#   ..$ postp_est  : num [1:16307] 0.298 0.294 0.294 0.294 0.295 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.284
#   ..$ h2_est     : num 0.00278
#   ..$ path_p_est : num [1:1500] 0.118 0.117 0.117 0.119 0.124 ...
#   ..$ path_h2_est: num [1:1500] 0.00402 0.00393 0.00376 0.00346 0.00336 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.115
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002551 0.000552 0.000561 0.000548 0.000563 ...
#   ..$ postp_est  : num [1:16307] 0.186 0.18 0.181 0.18 0.181 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.17
#   ..$ h2_est     : num 0.00277
#   ..$ path_p_est : num [1:1500] 0.153 0.152 0.151 0.147 0.148 ...
#   ..$ path_h2_est: num [1:1500] 0.00402 0.004 0.00388 0.00363 0.00329 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.154
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002582 0.000582 0.000583 0.000579 0.000591 ...
#   ..$ postp_est  : num [1:16307] 0.276 0.272 0.272 0.272 0.272 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.262
#   ..$ h2_est     : num 0.00279
#   ..$ path_p_est : num [1:1500] 0.205 0.2 0.192 0.188 0.188 ...
#   ..$ path_h2_est: num [1:1500] 0.00387 0.0037 0.00352 0.00378 0.00363 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.207
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002603 0.000578 0.000585 0.000586 0.000595 ...
#   ..$ postp_est  : num [1:16307] 0.237 0.232 0.232 0.232 0.233 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.223
#   ..$ h2_est     : num 0.00285
#   ..$ path_p_est : num [1:1500] 0.282 0.278 0.278 0.282 0.282 ...
#   ..$ path_h2_est: num [1:1500] 0.00357 0.00362 0.00356 0.00345 0.00339 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.278
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002651 0.000583 0.00059 0.000592 0.0006 ...
#   ..$ postp_est  : num [1:16307] 0.336 0.331 0.331 0.331 0.332 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.322
#   ..$ h2_est     : num 0.00285
#   ..$ path_p_est : num [1:1500] 0.367 0.369 0.373 0.373 0.371 ...
#   ..$ path_h2_est: num [1:1500] 0.00392 0.00389 0.00357 0.00361 0.00344 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.373
#  $ :List of 9
#   ..$ beta_est   : num [1:16307] 0.002671 0.000613 0.000621 0.000611 0.000624 ...
#   ..$ postp_est  : num [1:16307] 0.866 0.865 0.865 0.865 0.865 ...
#   ..$ sample_beta: num[1:16307, 0 ]
#   ..$ p_est      : num 0.863
#   ..$ h2_est     : num 0.00286
#   ..$ path_p_est : num [1:1500] 0.499 0.488 0.486 0.486 0.487 ...
#   ..$ path_h2_est: num [1:1500] 0.0037 0.00355 0.00336 0.003 0.00306 ...
#   ..$ h2_init    : num 0.00358
#   ..$ p_init     : num 0.5

# %%
test <- snp_fastImputeSimple(genotypes)

# %%
# get estimates with indicies corresponding to pred genotypes
beta_auto <- sapply(multi_auto, function(auto){
      auto$beta_est})

# perform matrix multiplication
pred_auto <- big_prodMat(
    test,
    beta_auto,
    ncores = NCORES)

# %%
# quality controls on chains
na_rows <- rowSums(is.na(pred_auto)) > 0 
na_rows_pct <- round(100*(sum(na_rows) / nrow(pred_auto)), 2)
write(paste0(na_rows_pct,"% of chain rows contains NAs (", args$out_prefix, ")" ), stdout())
# Out:
# 0% of chain rows contains NAs (data/prs/scores/auto/prs_auto_BMI_chr21)

# %%
sum(M)
# Out:
# [1] 10488

# %%
sc <- apply(pred_auto, 2, sd, na.rm = TRUE)
keep <- abs(sc - median(sc)) < 3 * mad(sc)
final_beta_auto <- rowMeans(beta_auto[, keep], na.rm = TRUE)

# %%
# get final predicton
final_pred_auto <- big_prodVec(
   genotypes,
   final_beta_auto,
   ncores = NCORES)

final_pred <- final_pred_auto
