# %%
setwd('/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/ukb_phasing')

# %%
library(data.table)
library(ggplot2)
library(Hmisc)
# Out:
# Loading required package: lattice
#
# Loading required package: survival
#
# Loading required package: Formula
#
#
# Attaching package: 'Hmisc'
#
#
# The following objects are masked from 'package:base':
#
#     format.pval, units

# %%
args <- list(
    #in_prefix = "/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb/data/phased/wes_union_calls/ligated/new/ukb_eur_wes_union_calls_200k_chr"
    in_prefix = "/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb/data/mt/annotated/ukb_eur_wes_200k_annot_chr"
)

# %%
files <- list.files(dirname(args$in_prefix), pattern = basename(args$in_prefix), full.names = TRUE)
files <- files[grepl(".trio",files)]

# %%
lst <- lapply(files, function(f) {
    d <- suppressWarnings(fread(f)) 
    d$CHR <- stringr::str_extract(f, "chr[0-9]+")
    return(d)
})

# %%
d <- do.call(rbind, lst)

# %%
colnames(d) <- c("trio","F",'M','O',"tested","mend","ser",'serpct',"chr")

# %%
errors <- aggregate(ser ~ chr, data = d, FUN = sum)
mend <- aggregate(mend ~ chr, data = d, FUN = sum)
tested <- aggregate(tested ~ chr, data = d, FUN = sum)

# %%
counts <- data.frame(errors)
counts$mend <- mend$mend
counts$tested <- tested$tested

# %%
counts_ci <- do.call(rbind, lapply(1:nrow(counts), function(i) Hmisc::binconf(counts$ser[i], counts$tested[i]) * 100))

# %%
final <- cbind(counts, counts_ci)

# %%
(121364 / 871347) * 483
# Out:
# [1] 67.27379

# %%
final
# Out:
#    chr   ser mend tested pointest     lower        upper
# 1  chr1  1   22   121364 0.0008239676 4.226401e-05 0.004667570
# 2  chr10 3    3    54300 0.0055248619 1.878969e-03 0.016243982
# 3  chr11 5    9    84613 0.0059092574 2.524107e-03 0.013833699
# 4  chr12 9   15    62906 0.0143070613 7.527398e-03 0.027191270
# 5  chr13 0   12    22009 0.0000000000 0.000000e+00 0.017450990
# 6  chr14 3   10    40936 0.0073285128 2.492386e-03 0.021546444
# 7  chr15 3   10    40217 0.0074595320 2.536946e-03 0.021931610
# 8  chr16 9   21    62790 0.0143334926 7.541304e-03 0.027241500
# 9  chr17 8    7    74000 0.0108108108 5.478205e-03 0.021333185
# 10 chr18 1    3    20865 0.0047927151 2.458341e-04 0.027145257
# 11 chr19 1   22    83696 0.0011948002 6.128524e-05 0.006768144
# 12 chr2  8   16    83398 0.0095925562 4.860864e-03 0.018929329
# 13 chr20 5    9    37670 0.0132731617 5.669630e-03 0.031070607
# 14 chr21 0    3    17857 0.0000000000 0.000000e+00 0.021507715
# 15 chr22 0    7    33470 0.0000000000 0.000000e+00 0.011476002
# 16 chr3  6   20    69129 0.0086794254 3.977917e-03 0.018936603
# 17 chr4  7    8    50270 0.0139248060 6.745461e-03 0.028743092
# 18 chr5  6    6    54191 0.0110719492 5.074469e-03 0.024156097
# 19 chr6  5   21    70980 0.0070442378 3.008914e-03 0.016490537
# 20 chr7  7   10    56234 0.0124479852 6.030044e-03 0.025694963
# 21 chr8  3    5    42433 0.0070699691 2.404456e-03 0.020786381
# 22 chr9  5   12    54517 0.0091714511 3.917557e-03 0.021469906

# %%
final_geno
# Out:
#    chr   ser mend tested pointest   lower      upper
# 1  chr1  483 1519 871347 0.05543142 0.05070463 0.06059858
# 2  chr10 316  980 538679 0.05866202 0.05254241 0.06549392
# 3  chr11 328  971 578568 0.05669169 0.05088087 0.06316572
# 4  chr12 303 1004 535867 0.05654388 0.05052700 0.06327682
# 5  chr13 240  793 354984 0.06760868 0.05958138 0.07671666
# 6  chr14 194  622 354197 0.05477178 0.04758926 0.06303765
# 7  chr15 227  615 359647 0.06311745 0.05542537 0.07187628
# 8  chr16 199  627 422085 0.04714690 0.04103684 0.05416622
# 9  chr17 218  558 414646 0.05257497 0.04604515 0.06003025
# 10 chr18 202  653 315523 0.06402069 0.05578199 0.07347530
# 11 chr19 123  404 325646 0.03777108 0.03166072 0.04506017
# 12 chr2  526 1718 855758 0.06146598 0.05643420 0.06694609
# 13 chr20 144  465 298582 0.04822796 0.04096930 0.05677193
# 14 chr22  78  266 205439 0.03796747 0.03042590 0.04737748
# 15 chr3  480 1503 715717 0.06706561 0.06132999 0.07333724
# 16 chr4  476 1558 660495 0.07206716 0.06587924 0.07883584
# 17 chr5  398 1291 632642 0.06291078 0.05702791 0.06940008
# 18 chr6  583 1470 801000 0.07278402 0.06711265 0.07893428
# 19 chr7  368 1170 542709 0.06780798 0.06122682 0.07509600
# 20 chr8  277 1119 533950 0.05187752 0.04611866 0.05835506
# 21 chr9  278  878 494155 0.05625765 0.05002326 0.06326854

# %%
rownames(final) <- NULL
colnames(final) <- tolower(colnames(final))

# %%
#final_geno <- final

# %%
final$chr <- factor(final$chr, levels = paste0("chr",1:22))

# %%
main <- "Switch errors after removing all genotyped sites"
ggplot(final, aes(y=chr, x=pointest, xmax=upper, xmin=lower)) +
    geom_point() +
    geom_errorbar() +
    xlab("(n_errors / n_switch) * 100") +
    ylab("chromosome") +
    theme_bw() +
    ggtitle(main)
# Out:
# plot without title

# %%
args <- list(
    in_prefix = "/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb/data/phased/wes_union_calls/ligated/new/ukb_eur_wes_union_calls_200k_chr"
    #in_prefix = "/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb/data/mt/annotated/ukb_eur_wes_200k_annot_chr"
)

# %%
files <- list.files(dirname(args$in_prefix), pattern = basename(args$in_prefix), full.names = TRUE)
files <- files[grepl(".txt",files)]

# %%
lst <- lapply(files, function(f) {
    d <- suppressWarnings(fread(f)) 
    d$CHR <- stringr::str_extract(f, "chr[0-9]+")
    return(d)
})

# %%
d <- do.call(rbind, lst)

# %%
d$locus <- paste0(d$CHR,":",d$POS)

# %%
variants <- fread("/well/lindgren/UKBIOBANK/dpalmer/wes_200k/ukb_wes_qc/data/variants/08_final_qc.keep.variant_list")

# %%
d$in_wes <- d$locus %in% variants$locus

# %%
counts <- aggregate(switches ~ wes + CHR, data = d, FUN = sum)

# %%
tested <- aggregate(switches ~ wes + CHR, data = d, FUN = length)

# %%
counts$tested <- tested$switches

# %%
counts_ci <- do.call(rbind, lapply(1:nrow(counts), function(i) Hmisc::binconf(counts$switches[i], counts$tested[i]) * 100))

# %%
counts <- cbind(counts, counts_ci)

# %%
rownames(counts) <- NULL
colnames(counts) <- tolower(colnames(counts))
counts$chr <- factor(counts$chr, levels = paste0("chr",1:22))

# %%
main <- "Switch errors calculated with hacked BCFtools"
ggplot(counts, aes(y=chr, x=pointest, xmax=upper, xmin=lower, color = wes)) +
    geom_point() +
    geom_errorbar() +
    xlab("(n_errors / n_switch) * 100") +
    ylab("chromosome") +
    theme_bw() +
    ggtitle(main)
# Out:
# plot without title

# %%
dwes <- d[d$CHR == "chr1"]
dwes$cumsum <- cumsum(d$switches)

# %%
ggplot(dwes, aes(x=POS, y=cumsum, color = in_wes) +
       geom_point()
