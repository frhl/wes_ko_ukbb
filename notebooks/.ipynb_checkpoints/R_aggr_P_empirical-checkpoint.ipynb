# %%
library(data.table)
setwd("/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb")
devtools::load_all('utils/modules/R/gwastools')
# Out:
# i Loading gwastools
#
# Loading required package: ggplot2
#
# Loading required package: stringr
#
# Warning message in setup_ns_exports(path, export_all, export_imports):
# "Objects listed as exports, but not present in namespace: summarize_bcftools_trio_stats"

# %%
files <- list.files("data/permute/permutations/", recursive = TRUE, full.names = TRUE, pattern = ".pvalues.txt.gz")

# %%
print(length(files))
# Out:
# [1] 1621

# %%
lst <- lapply(files, function(f) {
    d <- fread(f)
    p_cutoff <- d$p[!d$is_permuted]
    bool <- as.logical(d$is_permuted)
    values <- d$p[bool]
    p_lt_cutoff <- sum(values <= p_cutoff)
    p_empirical <- p_lt_cutoff / sum(d$is_permuted)
    chrom <- stringr::str_extract(f, "chr[0-9]+")
    gene <- stringr::str_extract(f, "ENSG[0-9]+")
    return(data.table(chrom, gene, p_empirical, p_cutoff))
})

# %%
ps <- do.call(rbind, lst)
bool_one <- ps$p_empirical == 1
ps <- ps[!bool_one,]
ps$p_expt <- get_expected_p(ps$p_empirical)

# %%
hist(ps$p_empirical)
# Out:
# Plot with title "Histogram of ps$p_empirical"

# %%
c(min(ps$p_expt), min(ps$p_empirical))
# Out:
# [1] 0.0007788162 0.0001130000

# %%
ps[ps$p_empirical == min(ps$p_empirical),]
# Out:
#   chrom gene            p_empirical p_cutoff p_expt
# 1 chr2  ENSG00000115504 0.000113    0.33662  0.0007788162

# %%
ribbon_p <- 0.95
n <- nrow(ps)
dplt <- data.table(
    pvalue.observed <- -log10(sort(ps$p_empirical)),
    pvalue.expected <- -log10(sort(ps$p_expt)),
    clower = -log10(qbeta(p = (1 - ribbon_p) / 2, shape2 = n:1, shape1 = 1:n)),
    cupper = -log10(qbeta(p = (1 + ribbon_p) / 2, shape2 = n:1, shape1 = 1:n))
)

# %%
ggplot(dplt, aes(x=pvalue.expected, y=pvalue.observed, ymax=cupper, ymin=clower)) +
    geom_ribbon(fill="grey80", color="black", alpha = 0.7, linetype = 'dashed') +
    geom_line() +
    geom_point() +
    geom_abline(linetype = 'dotted') + 
    scale_x_continuous(breaks=scales::pretty_breaks(n=10)) +
    scale_y_continuous(breaks=scales::pretty_breaks(n=10)) +
    xlab(expression(paste(-log[10],'(Expected P-value)' ))) +
    ylab(expression(paste(-log[10],'(Observed P-value)' ))) +
    #geom_hline(yintercept = -log10(bonf), linetype = 'dashed', color = 'red') +
    ggtitle("Empirical P-value for XXX") +
    theme(axis.title.x = element_text(margin=ggplot2::margin(t=10)),
          axis.title.y = element_text(margin=ggplot2::margin(r=10)),
          plot.title = element_text(hjust=0.5),
          plot.subtitle = element_text(hjust=0.5))
# Out:
# plot without title

# %%
ggplot(ps, aes(x=p_empirical)) +
    geom_histogram(bins = 15) +
    ggtitle(paste0(n, " p-values from unfinished empirical P of trait"))
# Out:
# plot without title
