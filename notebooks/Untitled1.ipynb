# %%
library(data.table)

# %%
setwd('/well/lindgren-ukbb/projects/ukbb-11867/flassen/projects/KO/wes_ko_ukbb')

# %%
files <- list.files('data/permute/permutations/', pattern = "*empirical_p.txt$", recursive = TRUE, full.names = TRUE)

# %%
files[grepl("ENSG00000109016", files)]
# Out:
# [1] "data/permute/permutations//chr17/ENSG00000109016/ukb_eur_wes_200k_pLoF_damaging_missense_permuted_chr17_ENSG00000109016_empirical_p.txt"

# %%
d <- do.call(rbind, lapply(files, fread, header = FALSE))

# %%
table(d$V7)
# Out:
#           OK    OK (gene) OK (min_mac)
#           34         1224          504

# %%
d <- d[d$V6 %in% c(NA) & ( ! d$V7 %in% c("OK (gene)", "OK (min_mac)")) | d$V7 %in% "OK" ]

# %%
d
# Out:
#        V1              V2                                V3       V4
# 1      ENSG00000092621 Alanine_aminotransferase_residual    10000 0.0242823
# 2      ENSG00000142609 Alanine_aminotransferase_residual    10000 0.9282300
# 3      ENSG00000169962 Alanine_aminotransferase_residual    10000 0.3263560
# 4      ENSG00000148606 Alanine_aminotransferase_residual    10000 0.9334390
# 5      ENSG00000110031 Alanine_aminotransferase_residual    10000 0.0409139
# 6      ENSG00000111266 Alanine_aminotransferase_residual    10000 0.6299350
# 7      ENSG00000134531 Alanine_aminotransferase_residual    10000 0.1139820
# 8      ENSG00000134531 Alanine_aminotransferase_residual   100000 0.1139820
# 9      ENSG00000134531 Alanine_aminotransferase_residual  1000000 0.1139820
# 10     ENSG00000134531 Alanine_aminotransferase_residual    10000 0.1139820
# 11     ENSG00000134531 Alanine_aminotransferase_residual   100000 0.1139820
# ...

# %%
path <- "data/permute/permutations/chr7/ENSG00000164692/ukb_eur_wes_200k_pLoF_damaging_missense_permuted_chr7_ENSG00000164692_Alanine_aminotransferase_residual_merged.txt.gz"

# %%
x <- fread(path, tmpdir = "data/tmp/rtmp/")

# %%
x[x$AC_Allele2 == 4]
# Out:
#         CHR    POS    MarkerID        Allele1 Allele2 AC_Allele2 AF_Allele2
# 1       chr7    1     ENSG00000164692 X       Y       4          1.20247e-05
# 2       chr7    2     ENSG00000164692 X       Y       4          1.20247e-05
# 3       chr7    4     ENSG00000164692 X       Y       4          1.20247e-05
# 4       chr7    8     ENSG00000164692 X       Y       4          1.20247e-05
# 5       chr7    9     ENSG00000164692 X       Y       4          1.20247e-05
# 6       chr7   13     ENSG00000164692 X       Y       4          1.20247e-05
# 7       chr7   14     ENSG00000164692 X       Y       4          1.20247e-05
# 8       chr7   16     ENSG00000164692 X       Y       4          1.20247e-05
# 9       chr7   17     ENSG00000164692 X       Y       4          1.20247e-05
# 10      chr7   18     ENSG00000164692 X       Y       4          1.20247e-05
# 11      chr7   19     ENSG00000164692 X       Y       4          1.20247e-05
# ...

# %%
table(x$MissingRate)
# Out:
#       0
# 6874256

# %%
0.0000001

# %%
0.0000001
# Out:
# [1] 1e-07

# %%
?fread
# Out:
# Warning message in seq_len(head.end.idx):
# "first element used of 'length.out' argument"
# ERROR while rich displaying an object: Error in seq_len(head.end.idx): argument must be coercible to non-negative integer
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
# ...

# %%
d <- fread('data/knockouts/alt/ukb_eur_wes_200k_chr7_maf0to5e-2_damaging_missense.tsv.gz', tmpdir = "data/tmp/rtmp/")

# %%
d <- d[d$gene_id %in% "ENSG00000164692",]
d
# Out:
#   gene_id         s       gts
# 1 ENSG00000164692 1326715 ["0|1","1|0"]
# 2 ENSG00000164692 1365568 ["0|1","0/1"]
# 3 ENSG00000164692 1466583 ["0/1","0/1"]
# 4 ENSG00000164692 1702288 ["0/1","0|1"]
# 5 ENSG00000164692 3717495 ["0|1","0/1"]
#   varid                                     hom_alt_n phased.a1 phased.a2
# 1 ["chr7:94427672:G:A","chr7:94430340:G:A"] 0         1         1
# 2 ["chr7:94399073:C:T","chr7:94429245:A:G"] 0         0         1
# 3 ["chr7:94427794:G:T","chr7:94427795:A:G"] 0         0         0
# 4 ["chr7:94401610:C:T","chr7:94427672:G:A"] 0         0         1
# 5 ["chr7:94425757:G:A","chr7:94429429:C:T"] 0         0         1
#   unphased.n pKO knockout
# 1 0          1.0 Compound heterozygote
# 2 1          0.5 Possible Compound heterozygote
# 3 2          0.5 Possible Compound heterozygote
# 4 1          0.5 Possible Compound heterozygote
# 5 1          0.5 Possible Compound heterozygote

# %%
d$DS <- d$pKO * 2

# %%
sum(d$pKO)
# Out:
# [1] 3
